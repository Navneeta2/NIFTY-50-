# %%
import pandas as pd
import yfinance as yf
from sqlalchemy import create_engine
import datetime

# %%
#Using pandas to load all Nifty stock symbols
nifty = pd.read_html("https://en.wikipedia.org/wiki/NIFTY_50")
nifty[1]
# Out:
#                        Company Name      Symbol                      Sector
# 0                       Adani Ports  ADANIPORTS              Infrastructure
# 1                  Apollo Hospitals  APOLLOHOSP                  Healthcare
# 2                      Asian Paints  ASIANPAINT              Consumer Goods
# 3                         Axis Bank    AXISBANK                     Banking
# 4                        Bajaj Auto  BAJAJ-AUTO                  Automobile
# 5                     Bajaj Finance  BAJFINANCE          Financial Services
# 6                     Bajaj Finserv  BAJAJFINSV          Financial Services
# 7                     Bharti Airtel  BHARTIARTL           Telecommunication
# 8                  Bharat Petroleum        BPCL          Energy - Oil & Gas
# 9              Britannia Industries   BRITANNIA              Consumer Goods
# 10                            Cipla       CIPLA             Pharmaceuticals
# 11                       Coal India   COALINDIA                      Metals
# 12              Divi's Laboratories    DIVISLAB             Pharmaceuticals
# 13         Dr. Reddy's Laboratories     DRREDDY             Pharmaceuticals
# 14                    Eicher Motors   EICHERMOT                  Automobile
# 15                Grasim Industries      GRASIM                      Cement
# 16                 HCL Technologies     HCLTECH      Information Technology
# 17                             HDFC        HDFC          Financial Services
# 18                        HDFC Bank    HDFCBANK                     Banking
# 19                        HDFC Life    HDFCLIFE          Financial Services
# 20                    Hero MotoCorp  HEROMOTOCO                  Automobile
# 21              Hindalco Industries    HINDALCO                      Metals
# 22               Hindustan Unilever  HINDUNILVR              Consumer Goods
# 23                       ICICI Bank   ICICIBANK                     Banking
# 24                    IndusInd Bank  INDUSINDBK                     Banking
# 25                          Infosys        INFY      Information Technology
# 26                      ITC Limited         ITC              Consumer Goods
# 27                        JSW Steel    JSWSTEEL                      Metals
# 28              Kotak Mahindra Bank   KOTAKBANK                     Banking
# 29                  Larsen & Toubro          LT                Construction
# 30              Mahindra & Mahindra         M&M                  Automobile
# 31                    Maruti Suzuki      MARUTI                  Automobile
# 32                     Nestlé India   NESTLEIND              Consumer Goods
# 33                             NTPC        NTPC              Energy - Power
# 34  Oil and Natural Gas Corporation        ONGC          Energy - Oil & Gas
# 35  Power Grid Corporation of India   POWERGRID              Energy - Power
# 36              Reliance Industries    RELIANCE          Energy - Oil & Gas
# 37              State Bank of India        SBIN                     Banking
# 38       SBI Life Insurance Company     SBILIFE          Financial Services
# 39                    Shree Cements    SHREECEM                      Cement
# 40               Sun Pharmaceutical   SUNPHARMA             Pharmaceuticals
# 41                      Tata Motors  TATAMOTORS                  Automobile
# 42                       Tata Steel   TATASTEEL                      Metals
# 43        Tata Consultancy Services         TCS      Information Technology
# 44           Tata Consumer Products  TATACONSUM              Consumer Goods
# 45                    Tech Mahindra       TECHM      Information Technology
# 46                    Titan Company       TITAN           Consumer Durables
# 47                 UltraTech Cement  ULTRACEMCO                      Cement
# 48        United Phosphorus Limited         UPL                   Chemicals
# 49                            Wipro       WIPRO  Information Technology[15]

# %%
#Saving all symbols in a list
symbols = nifty[1].Symbol
symbols
# Out:
# 0     ADANIPORTS
# 1     APOLLOHOSP
# 2     ASIANPAINT
# 3       AXISBANK
# 4     BAJAJ-AUTO
# 5     BAJFINANCE
# 6     BAJAJFINSV
# 7     BHARTIARTL
# 8           BPCL
# 9      BRITANNIA
# 10         CIPLA
# 11     COALINDIA
# 12      DIVISLAB
# 13       DRREDDY
# 14     EICHERMOT
# 15        GRASIM
# 16       HCLTECH
# 17          HDFC
# 18      HDFCBANK
# 19      HDFCLIFE
# 20    HEROMOTOCO
# 21      HINDALCO
# 22    HINDUNILVR
# 23     ICICIBANK
# 24    INDUSINDBK
# 25          INFY
# 26           ITC
# 27      JSWSTEEL
# 28     KOTAKBANK
# 29            LT
# 30           M&M
# 31        MARUTI
# 32     NESTLEIND
# 33          NTPC
# 34          ONGC
# 35     POWERGRID
# 36      RELIANCE
# 37          SBIN
# 38       SBILIFE
# 39      SHREECEM
# 40     SUNPHARMA
# 41    TATAMOTORS
# 42     TATASTEEL
# 43           TCS
# 44    TATACONSUM
# 45         TECHM
# 46         TITAN
# 47    ULTRACEMCO
# 48           UPL
# 49         WIPRO
# Name: Symbol, dtype: object

# %%
#Running a for loop to add ".NS" at the end of all symbols
nifty_symbols = [s for s in symbols + ".NS"]
nifty_symbols
# Out:
# ['ADANIPORTS.NS',
#  'APOLLOHOSP.NS',
#  'ASIANPAINT.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJFINANCE.NS',
#  'BAJAJFINSV.NS',
#  'BHARTIARTL.NS',
#  'BPCL.NS',
#  'BRITANNIA.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'DIVISLAB.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'GRASIM.NS',
#  'HCLTECH.NS',
#  'HDFC.NS',
#  'HDFCBANK.NS',
#  'HDFCLIFE.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'HINDUNILVR.NS',
#  'ICICIBANK.NS',
#  'INDUSINDBK.NS',
#  'INFY.NS',
#  'ITC.NS',
#  'JSWSTEEL.NS',
#  'KOTAKBANK.NS',
#  'LT.NS',
#  'M&M.NS',
#  'MARUTI.NS',
#  'NESTLEIND.NS',
#  'NTPC.NS',
#  'ONGC.NS',
#  'POWERGRID.NS',
#  'RELIANCE.NS',
#  'SBIN.NS',
#  'SBILIFE.NS',
#  'SHREECEM.NS',
#  'SUNPHARMA.NS',
#  'TATAMOTORS.NS',
#  'TATASTEEL.NS',
#  'TCS.NS',
#  'TATACONSUM.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'ULTRACEMCO.NS',
#  'UPL.NS',
#  'WIPRO.NS']

# %%
#Using Yahoo Finance to download share information for all symbols
infos = []

for symbol in nifty_symbols:
    inf = yf.Ticker(symbol).info
    infos.append(inf)

# %%
infos
# Out:
# [{'zip': '382421',
#   'sector': 'Industrials',
#   'fullTimeEmployees': 2736,
#   'longBusinessSummary': 'Adani Ports and Special Economic Zone Limited, together with its subsidiaries, develops, operates, and maintains port infrastructure facilities in India. It also engages in the ports related infrastructure development activities; and development of infrastructure at contiguous Special Economic Zone at Mundra. The company operates 13 domestic ports, which handle dry cargo, liquid cargo, crude, and containers in Gujarat, Maharashtra, Goa, Kerala, Andhra Pradesh, Tamil Nadu, and Odisha. In addition, the company operates rail, cold storage, warehouse, inland waterways, trucking, air freight stations, and logistics parks. Further, the company is involved in power distribution, generation, and transmission infrastructure business; gas distribution; and ownership and operation of harbor tugs, barges, port crafts, ocean towage, and offshore support vessel. Additionally, the company offers non-scheduled passenger airline, dredging, and hospital and related services; and marine services, such as pilotage, laying, and maintenance of buoys. The company as incorporated in 1998 and is headquartered in Ahmedabad, India.',
#   'city': 'Ahmedabad',
#   'phone': '91 79 2656 5555',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.adaniports.com',
#   'maxAge': 1,
#   'address1': 'Adani Corporate House',
#   'fax': '91 79 2555 5500',
#   'industry': 'Marine Shipping',
#   'address2': 'Shantigram Near Vaishnodevi Circle S G Highway',
#   'ebitdaMargins': 0.64014,
#   'profitMargins': 0.28441998,
#   'grossMargins': 0.68444,
#   'operatingCashflow': None,
#   'revenueGrowth': 0.018,
#   'operatingMargins': 0.46677,
#   'ebitda': 101786796032,
#   'targetLowPrice': 735,
#   'recommendationKey': 'buy',
#   'grossProfits': 105605900000,
#   'freeCashflow': None,
#   'targetMedianPrice': 871,
#   'currentPrice': 844.2,
#   'earningsGrowth': -0.207,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': 24,
#   'targetMeanPrice': 863.46,
#   'debtToEquity': 123.528,
#   'returnOnEquity': None,
#   'targetHighPrice': 1001,
#   'totalCash': 91311702016,
#   'totalDebt': 477347315712,
#   'totalRevenue': 159007899648,
#   'totalCashPerShare': 43.227,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 75.273,
#   'quickRatio': None,
#   'recommendationMean': 1.8,
#   'exchange': 'NSI',
#   'shortName': 'ADANI PORT SPECIAL',
#   'longName': 'Adani Ports and Special Economic Zone Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '19800000',
#   'quoteType': 'EQUITY',
#   'symbol': 'ADANIPORTS.NS',
#   'messageBoardId': 'finmb_27674009',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 14.603,
#   'beta3Year': None,
#   'enterpriseToEbitda': 22.812,
#   '52WeekChange': 0.16881013,
#   'morningStarRiskRating': None,
#   'forwardEps': 33.42,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 2112370048,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 180.288,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.19713,
#   'netIncomeToCommon': 45224800256,
#   'trailingEps': 21.41,
#   'lastDividendValue': 5,
#   'SandP52WeekChange': -0.1602686,
#   'priceToBook': 4.682508,
#   'heldPercentInsiders': 0.72209,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 717045093,
#   'beta': 0.801543,
#   'enterpriseValue': 2321915314176,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1285200000,
#   'lastSplitFactor': '5:1',
#   'legalType': None,
#   'lastDividendDate': 1657756800,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.179,
#   'priceToSalesTrailing12Months': 11.214348,
#   'dateShortInterest': None,
#   'pegRatio': 1.03,
#   'ytdReturn': None,
#   'forwardPE': 25.260324,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 863.4,
#   'regularMarketOpen': 861,
#   'twoHundredDayAverage': 768.2695,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 875,
#   'navPrice': None,
#   'averageDailyVolume10Day': 9159076,
#   'regularMarketPreviousClose': 863.4,
#   'fiftyDayAverage': 840.08,
#   'trailingAnnualDividendRate': 0,
#   'open': 861,
#   'toCurrency': None,
#   'averageVolume10days': 9159076,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 5,
#   'exDividendDate': 1657756800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 833.8,
#   'currency': 'INR',
#   'trailingPE': 39.430172,
#   'regularMarketVolume': 11597449,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 1783169941504,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 6076603,
#   'dayLow': 833.8,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 11597449,
#   'fiftyTwoWeekHigh': 987.85,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 651.95,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0055,
#   'bidSize': 0,
#   'dayHigh': 875,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 844.2,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/adaniports.com'},
#  {'zip': '600006',
#   'sector': 'Healthcare',
#   'fullTimeEmployees': 71113,
#   'longBusinessSummary': "Apollo Hospitals Enterprise Limited, together with its subsidiaries, provides healthcare services in India and internationally. The company's healthcare facilities comprise primary, secondary, and tertiary care facilities. Its tertiary care hospitals provide advanced healthcare services; and specialties in cardiac sciences, oncology, neurosciences, orthopedics, emergency, robotic surgery, and transplants. The company also provides other services, such as project consultancy, health insurance, medical colleges, medvarsity for e-learning, and research services. In addition, it operates pharmacies, primary care clinics, birthing centers, specialized birthing centers, single specialty clinics, primary health centers and diagnostic chains, dental clinics, and daycare and home healthcare centers. The company's footprint includes 9,911 beds, 4,529 pharmacies, and 1,734 national retail healthcare centers, as well as Apollo 24/7, an end-to-end omni-channel healthcare platform and www.apollopharmacy, an online pharmacy. Apollo Hospitals Enterprise Limited was incorporated in 1979 and is based in Chennai, India.",
#   'city': 'Chennai',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.apollohospitals.com',
#   'maxAge': 1,
#   'address1': 'Sunny Side Building',
#   'industry': 'Medical Care Facilities',
#   'address2': '3rd Floor East Block No. 8/17 Shafee Mohammed Road',
#   'ebitdaMargins': 0.13701999,
#   'profitMargins': 0.06014,
#   'grossMargins': 0.35833,
#   'operatingCashflow': None,
#   'revenueGrowth': 0.014,
#   'operatingMargins': 0.10507,
#   'ebitda': 20127950848,
#   'targetLowPrice': 2900,
#   'recommendationKey': 'buy',
#   'grossProfits': 51309000000,
#   'freeCashflow': None,
#   'targetMedianPrice': 4522,
#   'currentPrice': 4242.95,
#   'earningsGrowth': -0.352,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': 19,
#   'targetMeanPrice': 4426.63,
#   'debtToEquity': 69.212,
#   'returnOnEquity': None,
#   'targetHighPrice': 5700,
#   'totalCash': None,
#   'totalDebt': None,
#   'totalRevenue': 146894094336,
#   'totalCashPerShare': None,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 1021.563,
#   'quickRatio': None,
#   'recommendationMean': 2,
#   'exchange': 'NSI',
#   'shortName': 'APOLLO HOSPITALS.',
#   'longName': 'Apollo Hospitals Enterprise Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '19800000',
#   'quoteType': 'EQUITY',
#   'symbol': 'APOLLOHOSP.NS',
#   'messageBoardId': 'finmb_8888162',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 4.192,
#   'beta3Year': None,
#   'enterpriseToEbitda': 30.594,
#   '52WeekChange': -0.029097378,
#   'morningStarRiskRating': None,
#   'forwardEps': 81.6,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 143784992,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 391.092,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.49488,
#   'netIncomeToCommon': 8834299904,
#   'trailingEps': 61.44,
#   'lastDividendValue': 11.75,
#   'SandP52WeekChange': -0.1602686,
#   'priceToBook': 10.848982,
#   'heldPercentInsiders': 0.29649,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 100828991,
#   'beta': None,
#   'enterpriseValue': 615786545152,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1283385600,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1660780800,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.352,
#   'priceToSalesTrailing12Months': 4.2847724,
#   'dateShortInterest': None,
#   'pegRatio': 0.65,
#   'ytdReturn': None,
#   'forwardPE': 51.99694,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 4282.7,
#   'regularMarketOpen': 4335,
#   'twoHundredDayAverage': 4346.301,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0.048800003,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 4354.1,
#   'navPrice': None,
#   'averageDailyVolume10Day': 673729,
#   'regularMarketPreviousClose': 4282.7,
#   'fiftyDayAverage': 4306.857,
#   'trailingAnnualDividendRate': 0,
#   'open': 4335,
#   'toCurrency': None,
#   'averageVolume10days': 673729,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 11.75,
#   'exDividendDate': 1660780800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 4205,
#   'currency': 'INR',
#   'trailingPE': 69.05843,
#   'regularMarketVolume': 651046,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 629407744000,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 557845,
#   'dayLow': 4205,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 651046,
#   'fiftyTwoWeekHigh': 5935.4,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 0.35,
#   'fiftyTwoWeekLow': 3361.55,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0027,
#   'bidSize': 0,
#   'dayHigh': 4354.1,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 4242.95,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/apollohospitals.com'},
#  {'zip': '400055',
#   'sector': 'Basic Materials',
#   'fullTimeEmployees': 7423,
#   'longBusinessSummary': 'Asian Paints Limited, together with its subsidiaries, manufactures, sells, and distributes paints and coatings for decorative and industrial use in India and internationally. It operates in Paints and Home Improvement segments. The company offers decorative coatings for interior and exterior walls, metal finishes, and wood finishes; paints; wall coverings; textures painting aid; waterproofing; wall stickers; mechanised tools; adhesives; modular kitchens; wardrobes; bath fittings and sanitaryware; home décor products; sanitizers and surface disinfectants; furniture, furnishings; and lightings, as well as enamels and thinners. The company offers its products under the Asian Paints, Apco Coatings, Asian Paints Berger, Asian Paints Causeway, SCIB Paints, Taubmans, and Kadisco Asian Paints through a network of dealers and retail stores, as well as operates asianpaints.com, an online shop. Asian Paints Limited was founded in 1942 and is headquartered in Mumbai, India.',
#   'city': 'Mumbai',
#   'phone': '91 22 6218 1000',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.asianpaints.com',
#   'maxAge': 1,
#   'address1': 'Asian Paints House',
#   'fax': '91 22 6218 1111',
#   'industry': 'Specialty Chemicals',
#   'address2': '6A, Shantinagar',
#   'ebitdaMargins': 0.16174999,
#   'profitMargins': 0.10876001,
#   'grossMargins': 0.36358002,
#   'operatingCashflow': None,
#   'revenueGrowth': 0.536,
#   'operatingMargins': 0.1445,
#   'ebitda': 51740774400,
#   'targetLowPrice': 1679,
#   'recommendationKey': 'hold',
#   'grossProfits': 105088200000,
#   'freeCashflow': None,
#   'targetMedianPrice': 3106.5,
#   'currentPrice': 3470.65,
#   'earningsGrowth': 0.788,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': 38,
#   'targetMeanPrice': 3027.95,
#   'debtToEquity': 11.176,
#   'returnOnEquity': None,
#   'targetHighPrice': 3670,
#   'totalCash': 40367898624,
#   'totalDebt': 15868800000,
#   'totalRevenue': 319870205952,
#   'totalCashPerShare': 42.085,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 333.459,
#   'quickRatio': None,
#   'recommendationMean': 3.1,
#   'exchange': 'NSI',
#   'shortName': 'ASIAN PAINTS LTD',
#   'longName': 'Asian Paints Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '19800000',
#   'quoteType': 'EQUITY',
#   'symbol': 'ASIANPAINT.NS',
#   'messageBoardId': 'finmb_878276',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 10.245,
#   'beta3Year': None,
#   'enterpriseToEbitda': 63.338,
#   '52WeekChange': 0.017264843,
#   'morningStarRiskRating': None,
#   'forwardEps': 28.24,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 959198016,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 143.991,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.17167999,
#   'netIncomeToCommon': 34789998592,
#   'trailingEps': 36.27,
#   'lastDividendValue': 15.5,
#   'SandP52WeekChange': -0.1602686,
#   'priceToBook': 24.103243,
#   'heldPercentInsiders': 0.50044,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 467992602,
#   'beta': 0.391341,
#   'enterpriseValue': 3277146292224,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1375142400,
#   'lastSplitFactor': '10:1',
#   'legalType': None,
#   'lastDividendDate': 1654732800,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.789,
#   'priceToSalesTrailing12Months': 10.402872,
#   'dateShortInterest': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': 122.89837,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 3438.05,
#   'regularMarketOpen': 3454.85,
#   'twoHundredDayAverage': 3140.967,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0.528,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 3500,
#   'navPrice': None,
#   'averageDailyVolume10Day': 888097,
#   'regularMarketPreviousClose': 3438.05,
#   'fiftyDayAverage': 3362.506,
#   'trailingAnnualDividendRate': 0,
#   'open': 3454.85,
#   'toCurrency': None,
#   'averageVolume10days': 888097,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 19.15,
#   'exDividendDate': 1654732800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 3431.05,
#   'currency': 'INR',
#   'trailingPE': 95.68927,
#   'regularMarketVolume': 1455240,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 3327568904192,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 1118537,
#   'dayLow': 3431.05,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 1455240,
#   'fiftyTwoWeekHigh': 3590,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 0.6,
#   'fiftyTwoWeekLow': 2560,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0056,
#   'bidSize': 0,
#   'dayHigh': 3500,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 3470.65,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/asianpaints.com'},
#  {'zip': '400025',
#   'sector': 'Financial Services',
#   'fullTimeEmployees': 86400,
#   'longBusinessSummary': 'Axis Bank Limited provides various financial products and services. It operates through four segments: Treasury, Retail Banking, Corporate/Wholesale Banking, and Other Banking Business. The Treasury segment is involved in investments in sovereign and corporate debt, and equity and mutual funds, as well as in trading operations, derivative trading, and foreign exchange operations. The Retail Banking segment engages in the provision of lending services to individuals/small businesses; liability products, card services, internet banking, mobile banking, ATM services, depository, financial advisory services, and NRI services. The Corporate/Wholesale Banking segment offers corporate advisory, placements and syndication, project appraisals, capital market related, and cash management services. The Other Banking Business segment is involved in para banking activities. The company operates 4,759 branches; 10,161 ATMs; and 6,063 recyclers in India. It also has eight international offices with branches at Singapore, Dubai, and Gift City, India; and representative offices in Dhaka, Dubai, Abu Dhabi, and Sharjah. The company was formerly known as UTI Bank Limited and changed its name to Axis Bank Limited in July 2007. Axis Bank Limited was incorporated in 1993 and is based in Mumbai, India.',
#   'city': 'Mumbai',
#   'phone': '91 22 2425 2525',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.axisbank.com',
#   'maxAge': 1,
#   'address1': 'Axis House',
#   'fax': '91 22 2425 1800',
#   'industry': 'Banks—Regional',
#   'address2': 'C-2, Wadia International Centre Pandurang Budhkar Marg Worli',
#   'ebitdaMargins': 0,
#   'profitMargins': 0.37225,
#   'grossMargins': 0,
#   'operatingCashflow': None,
#   'revenueGrowth': 0.523,
#   'operatingMargins': 0.38887,
#   'ebitda': None,
#   'targetLowPrice': None,
#   'recommendationKey': 'none',
#   'grossProfits': 389885800000,
#   'freeCashflow': None,
#   'targetMedianPrice': None,
#   'currentPrice': 737.5,
#   'earningsGrowth': 0.855,
#   'currentRatio': None,
#   'returnOnAssets': 0.01474,
#   'numberOfAnalystOpinions': None,
#   'targetMeanPrice': None,
#   'debtToEquity': None,
#   'returnOnEquity': 0.14145,
#   'targetHighPrice': None,
#   'totalCash': 491438604288,
#   'totalDebt': 1869655572480,
#   'totalRevenue': 433654104064,
#   'totalCashPerShare': 160.089,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 141.36,
#   'quickRatio': None,
#   'recommendationMean': None,
#   'exchange': 'NSI',
#   'shortName': 'AXIS BANK',
#   'longName': 'Axis Bank Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '19800000',
#   'quoteType': 'EQUITY',
#   'symbol': 'AXISBANK.NS',
#   'messageBoardId': 'finmb_3729884',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 8.626,
#   'beta3Year': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': -0.059047163,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 3072209920,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 400.581,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.65556,
#   'netIncomeToCommon': 161429700608,
#   'trailingEps': 51.1,
#   'lastDividendValue': 1,
#   'SandP52WeekChange': -0.1602686,
#   'priceToBook': 1.8410759,
#   'heldPercentInsiders': 0.03126,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 2607448731,
#   'beta': 1.358336,
#   'enterpriseValue': 3740802744320,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1406505600,
#   'lastSplitFactor': '5:1',
#   'legalType': None,
#   'lastDividendDate': 1657152000,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.859,
#   'priceToSalesTrailing12Months': 5.2247977,
#   'dateShortInterest': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 742.6,
#   'regularMarketOpen': 746.35,
#   'twoHundredDayAverage': 724.91125,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0.0191,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 754.15,
#   'navPrice': None,
#   'averageDailyVolume10Day': 9328884,
#   'regularMarketPreviousClose': 742.6,
#   'fiftyDayAverage': 753.067,
#   'trailingAnnualDividendRate': 0,
#   'open': 746.35,
#   'toCurrency': None,
#   'averageVolume10days': 9328884,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 1,
#   'exDividendDate': 1657152000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 730.5,
#   'currency': 'INR',
#   'trailingPE': 14.432486,
#   'regularMarketVolume': 11358009,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 2265754894336,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 8620624,
#   'dayLow': 730.5,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 11358009,
#   'fiftyTwoWeekHigh': 866.9,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 618.25,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0013,
#   'bidSize': 0,
#   'dayHigh': 754.15,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 737.5,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/axisbank.com'},
#  {'zip': '411035',
#   'sector': 'Consumer Cyclical',
#   'fullTimeEmployees': 10134,
#   'longBusinessSummary': 'Bajaj Auto Limited develops, manufactures, and distributes automobiles in India. It operates through Automotive and Investments segments. The company offers motorcycles, commercial vehicles, electric two-wheelers, etc., as well as related parts. It also exports its products. The company was founded in 1945 and is based in Pune, India.',
#   'city': 'Pune',
#   'phone': '91 20 2747 2851',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.bajajauto.com',
#   'maxAge': 1,
#   'address1': 'Mumbai-Pune Road',
#   'fax': '91 20 2740 7380',
#   'industry': 'Auto Manufacturers',
#   'address2': 'Akurdi',
#   'ebitdaMargins': 0.19052,
#   'profitMargins': 0.17649001,
#   'grossMargins': 0.28765,
#   'operatingCashflow': None,
#   'revenueGrowth': 0.079,
#   'operatingMargins': 0.18271999,
#   'ebitda': 66486173696,
#   'targetLowPrice': 3000,
#   'recommendationKey': 'buy',
#   'grossProfits': 98092900000,
#   'freeCashflow': None,
#   'targetMedianPrice': 4280,
#   'currentPrice': 3541.9,
#   'earningsGrowth': -0.007,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': 45,
#   'targetMeanPrice': 4226.76,
#   'debtToEquity': None,
#   'returnOnEquity': None,
#   'targetHighPrice': 5378,
#   'totalCash': 59028201472,
#   'totalDebt': 0,
#   'totalRevenue': 348966289408,
#   'totalCashPerShare': 203.978,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 1206.414,
#   'quickRatio': None,
#   'recommendationMean': 2.2,
#   'exchange': 'NSI',
#   'shortName': 'BAJAJ AUTO LTD',
#   'longName': 'Bajaj Auto Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '19800000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BAJAJ-AUTO.NS',
#   'messageBoardId': 'finmb_32669680',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 2.898,
#   'beta3Year': None,
#   'enterpriseToEbitda': 15.212,
#   '52WeekChange': -0.08550155,
#   'morningStarRiskRating': None,
#   'forwardEps': 171.22,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 283670016,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 1033.043,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.16595,
#   'netIncomeToCommon': 61590298624,
#   'trailingEps': 211.19,
#   'lastDividendValue': 140,
#   'SandP52WeekChange': -0.1602686,
#   'priceToBook': 3.4286084,
#   'heldPercentInsiders': 0.58529997,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 117452922,
#   'beta': 0.917702,
#   'enterpriseValue': 1011380191232,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1283904000,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1656547200,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.006,
#   'priceToSalesTrailing12Months': 2.8786957,
#   'dateShortInterest': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': 20.68625,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 3574.5,
#   'regularMarketOpen': 3590,
#   'twoHundredDayAverage': 3685.556,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 1.3152001,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 3594.95,
#   'navPrice': None,
#   'averageDailyVolume10Day': 376191,
#   'regularMarketPreviousClose': 3574.5,
#   'fiftyDayAverage': 3949.558,
#   'trailingAnnualDividendRate': 0,
#   'open': 3590,
#   'toCurrency': None,
#   'averageVolume10days': 376191,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 140,
#   'exDividendDate': 1656547200,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 3510.1,
#   'currency': 'INR',
#   'trailingPE': 16.771152,
#   'regularMarketVolume': 344197,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 1004567789568,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 423779,
#   'dayLow': 3510.1,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 344197,
#   'fiftyTwoWeekHigh': 4131.75,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 3027.05,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0378,
#   'bidSize': 0,
#   'dayHigh': 3594.95,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 3541.9,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/bajajauto.com'},
#  {'zip': '411014',
#   'sector': 'Financial Services',
#   'fullTimeEmployees': 35425,
#   'longBusinessSummary': 'Bajaj Finance Limited operates as a non-banking financial company in India. The company offers consumer durable, lifestyle, lifecare, digital product, two and three wheeler, developer, used car, medical equipment, vendor, light engineering, specialty chemicals, financial institution, corporate, and warehouse finance services; IPO and ESOP finance, margin trading finance, trading account, depository, and HNI and retail broking services; personal, gold, home, business, working capital, secured enterprise, and professional loans; and loan against fixed deposits, shares, properties, and securities. It also provides life, general, and health insurance, as well as pocket insurance products; extended warranty, e-commerce, and lease rental discounting services; financial fitness reports; and EMI cards, and co-branded credit cards and wallets, as well as offers investment services, such as systematic deposit plan, fixed and term deposits, and mutual funds. The company was formerly known as Bajaj Auto Finance Limited and changed its name to Bajaj Finance Limited. The company was incorporated in 1987 and is based in Pune, India. Bajaj Finance Limited is a subsidiary of Bajaj Finserv Limited.',
#   'city': 'Pune',
#   'phone': '91 20 7157 6403',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.bajajfinserv.in/corporate-bajaj-finance',
#   'maxAge': 1,
#   'address1': 'Panchshil Tech Park',
#   'fax': '91 20 7157 6364',
#   'industry': 'Credit Services',
#   'address2': '3rd Floor Viman Nagar',
#   'ebitdaMargins': 0,
#   'profitMargins': 0.42613998,
#   'grossMargins': 0.90038,
#   'operatingCashflow': None,
#   'revenueGrowth': 1.148,
#   'operatingMargins': 0.57655,
#   'ebitda': None,
#   'targetLowPrice': None,
#   'recommendationKey': 'none',
#   'grossProfits': 152511100000,
#   'freeCashflow': None,
#   'targetMedianPrice': None,
#   'currentPrice': 7242.85,
#   'earningsGrowth': 1.586,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': None,
#   'targetMeanPrice': None,
#   'debtToEquity': 308.898,
#   'returnOnEquity': None,
#   'targetHighPrice': None,
#   'totalCash': 53774000128,
#   'totalDebt': 1350274777088,
#   'totalRevenue': 202325999616,
#   'totalCashPerShare': 89.136,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 335.52,
#   'quickRatio': None,
#   'recommendationMean': None,
#   'exchange': 'NSI',
#   'shortName': 'BAJAJ FINANCE LTD',
#   'longName': 'Bajaj Finance Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '19800000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BAJFINANCE.NS',
#   'messageBoardId': 'finmb_881576',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 28.054,
#   'beta3Year': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': -0.03762281,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 605428992,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 724.584,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.20771,
#   'netIncomeToCommon': 86220398592,
#   'trailingEps': 142.03,
#   'lastDividendValue': 20,
#   'SandP52WeekChange': -0.1602686,
#   'priceToBook': 9.995873,
#   'heldPercentInsiders': 0.56608003,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 261485614,
#   'beta': 1.234033,
#   'enterpriseValue': 5676010569728,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1473292800,
#   'lastSplitFactor': '5:1',
#   'legalType': None,
#   'lastDividendDate': 1656547200,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 1.59,
#   'priceToSalesTrailing12Months': 21.671812,
#   'dateShortInterest': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 7259.5,
#   'regularMarketOpen': 7325,
#   'twoHundredDayAverage': 6741.8794,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0.21120001,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 7379.95,
#   'navPrice': None,
#   'averageDailyVolume10Day': 1384994,
#   'regularMarketPreviousClose': 7259.5,
#   'fiftyDayAverage': 7146.84,
#   'trailingAnnualDividendRate': 0,
#   'open': 7325,
#   'toCurrency': None,
#   'averageVolume10days': 1384994,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 20,
#   'exDividendDate': 1656547200,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 7210.05,
#   'currency': 'INR',
#   'trailingPE': 50.995213,
#   'regularMarketVolume': 1142808,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 4384771014656,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 1228230,
#   'dayLow': 7210.05,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 1142808,
#   'fiftyTwoWeekHigh': 8050,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 5220,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0027,
#   'bidSize': 0,
#   'dayHigh': 7379.95,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 7242.85,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/bajajfinserv.in'},
#  {'zip': '411014',
#   'sector': 'Financial Services',
#   'fullTimeEmployees': 59961,
#   'longBusinessSummary': 'Bajaj Finserv Ltd., through its subsidiaries, provides financial services in India. The company operates through Life Insurance, General Insurance, Windmill, Retail Financing, and Investments and Others segments. It offers personal, business, home, commercial, and gold loans; two and three wheeler loans; mortgages; unsecured and secured loans; loans against securities and properties; financing for products, such as consumer durable, digital, lifecare, furniture, etc.; and lease rental discounting products. The company also provides investment products, including fixed and term deposits, demat accounts, systematic deposit plans, and mutual funds; life, health, motor, car, two-wheeler, marine, home, crop, pocket, and travel insurance products; finance for professionals; savings products, wealth management and retirement planning services, and annuities; healthcare needs for the family; extended warranty, asset care, and financial fitness report services; and wallets and credit cards. In addition, it offers payments; SME finance products; and trading account, depository, margin trading, and HNI and retail broking services. Further, the company owns and operates 138 windmills with total installed capacity of 65.2 megawatts. Bajaj Finserv Ltd. was incorporated in 2007 and is based in Pune, India.',
#   'city': 'Pune',
#   'phone': '91 20 7157 6064',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.bajajfinserv.in/corporate-bajaj-finserv',
#   'maxAge': 1,
#   'address1': 'Bajaj Finserv Corporate Office',
#   'industry': 'Financial Conglomerates',
#   'address2': '6th Floor Off Pune-Ahmednagar Road Viman Nagar',
#   'ebitdaMargins': 0.33668998,
#   'profitMargins': 0.073,
#   'grossMargins': 0.49178,
#   'operatingCashflow': None,
#   'revenueGrowth': 0.132,
#   'operatingMargins': 0.33303002,
#   'ebitda': 232135770112,
#   'targetLowPrice': 12000,
#   'recommendationKey': 'buy',
#   'grossProfits': 306351800000,
#   'freeCashflow': None,
#   'targetMedianPrice': 13400,
#   'currentPrice': 1679.55,
#   'earningsGrowth': 0.574,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': 9,
#   'targetMeanPrice': 14250.8,
#   'debtToEquity': 196.803,
#   'returnOnEquity': None,
#   'targetHighPrice': 20200,
#   'totalCash': 84367499264,
#   'totalDebt': 1305196756992,
#   'totalRevenue': 689474109440,
#   'totalCashPerShare': 53.015,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 433.346,
#   'quickRatio': None,
#   'recommendationMean': 2,
#   'exchange': 'NSI',
#   'shortName': 'BAJAJ FINSERV LTD',
#   'longName': 'Bajaj Finserv Ltd.',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '19800000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BAJAJFINSV.NS',
#   'messageBoardId': 'finmb_41356562',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 6.019,
#   'beta3Year': None,
#   'enterpriseToEbitda': 17.877,
#   '52WeekChange': -0.04457748,
#   'morningStarRiskRating': None,
#   'forwardEps': 49.41,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 1592819968,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 252.906,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.10155,
#   'netIncomeToCommon': 50333798400,
#   'trailingEps': 30.8,
#   'lastDividendValue': 0.4,
#   'SandP52WeekChange': -0.1602686,
#   'priceToBook': 6.641005,
#   'heldPercentInsiders': 0.66799,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 524485188,
#   'beta': 1.31033,
#   'enterpriseValue': 4149977284608,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1663027200,
#   'lastSplitFactor': '5:1',
#   'legalType': None,
#   'lastDividendDate': 1656547200,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.572,
#   'priceToSalesTrailing12Months': 3.9852505,
#   'dateShortInterest': None,
#   'pegRatio': 1.78,
#   'ytdReturn': None,
#   'forwardPE': 33.992107,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 1676.8,
#   'regularMarketOpen': 1688.5,
#   'twoHundredDayAverage': 1510.8364,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0.0221,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 1715.75,
#   'navPrice': None,
#   'averageDailyVolume10Day': 3990534,
#   'regularMarketPreviousClose': 1676.8,
#   'fiftyDayAverage': 1600.346,
#   'trailingAnnualDividendRate': 0,
#   'open': 1688.5,
#   'toCurrency': None,
#   'averageVolume10days': 3990534,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 0.4,
#   'exDividendDate': 1656547200,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 1665,
#   'currency': 'INR',
#   'trailingPE': 54.530846,
#   'regularMarketVolume': 2623637,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 2747727085568,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 4299553,
#   'dayLow': 1665,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 2623637,
#   'fiftyTwoWeekHigh': 1932.5,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 1072.72,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0002,
#   'bidSize': 0,
#   'dayHigh': 1715.75,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 1679.55,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/bajajfinserv.in'},
#  {'zip': '110070',
#   'sector': 'Communication Services',
#   'fullTimeEmployees': 18000,
#   'longBusinessSummary': "Bharti Airtel Limited operates as a telecommunications company in Asia and Africa. It operates through Mobile Services India, Mobile Services Africa, Mobile Services South Asia, Airtel Business, Tower Infrastructure Services, Homes Services, Digital TV Services, and Others segments. The company's product offerings include 2G, 3G, and 4G wireless services, as well as mobile commerce, fixed line services, high speed home broadband, DTH, and enterprise services, including national and international long distance services to carriers. It also provides voice, data, video, network integration, data center, and managed services, as well as enterprise mobility applications; on-demand entertainment and streaming services, such as music and video; digital payments and financial services; and cloud and data center, cybersecurity, IoT, Ad Tech, and cloud based communication products. In addition, the company operates a submarine cable system; and provides telecom towers and related infrastructure for various mobile operators. As of August 5, 2021, it had approximately 474 million customers across its operations. Bharti Airtel Limited has collaboration with Qualcomm Technologies, Inc. for accelerating 5G; partnership with Google Cloud and Cisco to launch Airtel Office Internet, a unified enterprise grade solution; and a strategic partnership with Tata Consultancy Services Limited for implementing 5G network solutions for India. The company was formerly known as Bharti Tele-Ventures Limited and changed its name to Bharti Airtel Limited in April 2006. Bharti Airtel Limited was incorporated in 1995 and is headquartered in New Delhi, India.",
#   'city': 'New Delhi',
#   'phone': '91 11 4666 6100',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.airtel.in',
#   'maxAge': 1,
#   'address1': 'Bharti Crescent',
#   'fax': '91 11 4166 6137',
#   'industry': 'Telecom Services',
#   'address2': '1, Nelson Mandela Road Vasant Kunj Phase - II',
#   'ebitdaMargins': 0.42707002,
#   'profitMargins': 0.04535,
#   'grossMargins': 0.60174,
#   'operatingCashflow': None,
#   'revenueGrowth': 0.219,
#   'operatingMargins': 0.22313,
#   'ebitda': 525356236800,
#   'targetLowPrice': None,
#   'recommendationKey': 'none',
#   'grossProfits': 698027000000,
#   'freeCashflow': None,
#   'targetMedianPrice': None,
#   'currentPrice': 760.6,
#   'earningsGrowth': 4.462,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': None,
#   'targetMeanPrice': None,
#   'debtToEquity': 181.076,
#   'returnOnEquity': None,
#   'targetHighPrice': None,
#   'totalCash': 91891998720,
#   'totalDebt': 1696778944512,
#   'totalRevenue': 1230145978368,
#   'totalCashPerShare': 15.625,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 220.527,
#   'quickRatio': None,
#   'recommendationMean': None,
#   'exchange': 'NSI',
#   'shortName': 'BHARTI AIRTEL LTD',
#   'longName': 'Bharti Airtel Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '19800000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BHARTIARTL.NS',
#   'messageBoardId': 'finmb_135466',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 5.135,
#   'beta3Year': None,
#   'enterpriseToEbitda': 12.024,
#   '52WeekChange': 0.0846082,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 5952580096,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 113.164,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.31173,
#   'netIncomeToCommon': 55782998016,
#   'trailingEps': 9.96,
#   'lastDividendValue': 3,
#   'SandP52WeekChange': -0.1602686,
#   'priceToBook': 6.7212186,
#   'heldPercentInsiders': 0.59262,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 2631917016,
#   'beta': 0.450064,
#   'enterpriseValue': 6317036011520,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1248393600,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1659312000,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 4.668,
#   'priceToSalesTrailing12Months': 3.6804836,
#   'dateShortInterest': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 755.05,
#   'regularMarketOpen': 758.85,
#   'twoHundredDayAverage': 709.16223,
#   'trailingAnnualDividendYield': 0.003973247,
#   'payoutRatio': 0,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 765,
#   'navPrice': None,
#   'averageDailyVolume10Day': 9447799,
#   'regularMarketPreviousClose': 755.05,
#   'fiftyDayAverage': 727.561,
#   'trailingAnnualDividendRate': 3,
#   'open': 758.85,
#   'toCurrency': None,
#   'averageVolume10days': 9447799,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 3,
#   'exDividendDate': 1659312000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 757.2,
#   'currency': 'INR',
#   'trailingPE': 76.365456,
#   'regularMarketVolume': 5964990,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 4527532015616,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 9413818,
#   'dayLow': 757.2,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 5964990,
#   'fiftyTwoWeekHigh': 797,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 628.75,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.004,
#   'bidSize': 0,
#   'dayHigh': 765,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 760.6,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/airtel.in'},
#  {'zip': '400001',
#   'sector': 'Energy',
#   'fullTimeEmployees': 8594,
#   'longBusinessSummary': 'Bharat Petroleum Corporation Limited refines crude oil and markets petroleum products in India. The company operates through two segments, Downstream Petroleum; and Exploration and Production of Hydrocarbons. It operates fuel stations that sell petrol, diesel, automotive liquefied petroleum gas (LPG), and compressed natural gas. The company operates a network of 18,622 fuel stations. It also provides Bharatgas fuels to approximately 8 crore households; MAK lubricants, such as automotive engine oils, gear oils, greases, and specialties, as well as industrial lubricants; and jet fuel and services to airlines, as well as operates oil refineries in Mumbai, Bina, and Kochi. In addition, the company offers industrial fuels products, such as white oil, black oil, bitumen, sulphur, petcoke, propylene, petchem, and solvents products; and bunkering facilities. Further, it has participating interests in eighteen blocks, including nine blocks in India and nine blocks in other countries; imports and exports petroleum products; and owns a network of 2,596 km of multi-product pipelines, as well as engages in the natural gas business. The company was formerly known as Bharat Refineries Limited and changed its name to Bharat Petroleum Corporation Limited in August 1977. Bharat Petroleum Corporation Limited was incorporated in 1952 and is based in Mumbai, India.',
#   'city': 'Mumbai',
#   'phone': '91 22 2271 3000',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.bharatpetroleum.in',
#   'maxAge': 1,
#   'address1': 'Bharat Bhavan',
#   'fax': '91 22 2271 3874',
#   'industry': 'Oil & Gas Refining & Marketing',
#   'address2': '4 & 6 Currimbhoy Road Ballard Estate PB No. 688',
#   'ebitdaMargins': 0.02665,
#   'profitMargins': 0.0058399998,
#   'grossMargins': 0.09585,
#   'operatingCashflow': None,
#   'revenueGrowth': 0.707,
#   'operatingMargins': 0.01397,
#   'ebitda': 105800949760,
#   'targetLowPrice': 245,
#   'recommendationKey': 'buy',
#   'grossProfits': 433898100000,
#   'freeCashflow': None,
#   'targetMedianPrice': 390,
#   'currentPrice': 310.65,
#   'earningsGrowth': None,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': 31,
#   'targetMeanPrice': 391.87,
#   'debtToEquity': 124.33,
#   'returnOnEquity': None,
#   'targetHighPrice': 510,
#   'totalCash': 52945801216,
#   'totalDebt': 645341970432,
#   'totalRevenue': 3969246560256,
#   'totalCashPerShare': 24.407,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 1863.941,
#   'quickRatio': None,
#   'recommendationMean': 2.1,
#   'exchange': 'NSI',
#   'shortName': 'BHARAT PETROL CORP',
#   'longName': 'Bharat Petroleum Corporation Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '19800000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BPCL.NS',
#   'messageBoardId': 'finmb_4481079',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 0.316,
#   'beta3Year': None,
#   'enterpriseToEbitda': 11.851,
#   '52WeekChange': -0.29027003,
#   'morningStarRiskRating': None,
#   'forwardEps': 41.84,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 2169250048,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 239.279,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.24583,
#   'netIncomeToCommon': 23193999360,
#   'trailingEps': 10.89,
#   'lastDividendValue': 6,
#   'SandP52WeekChange': -0.1602686,
#   'priceToBook': 1.2982751,
#   'heldPercentInsiders': 0.54668,
#   'nextFiscalYearEnd': 1711843200,
# ...
#   'maxAge': 1,
#   'address1': 'Ahura Centre',
#   'fax': '91 22 6692 8109',
#   'industry': 'Building Materials',
#   'address2': "'B' Wing, 2nd floor Mahakali Caves Road Andheri (East)",
#   'ebitdaMargins': 0.20236999,
#   'profitMargins': 0.12919,
#   'grossMargins': 0.59736997,
#   'operatingCashflow': None,
#   'revenueGrowth': 0.282,
#   'operatingMargins': 0.15289,
#   'ebitda': 113190797312,
#   'targetLowPrice': 6300,
#   'recommendationKey': 'buy',
#   'grossProfits': 324965800000,
#   'freeCashflow': None,
#   'targetMedianPrice': 8205,
#   'currentPrice': 6192.85,
#   'earningsGrowth': -0.069,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': 37,
#   'targetMeanPrice': 8137.57,
#   'debtToEquity': 23.006,
#   'returnOnEquity': None,
#   'targetHighPrice': 9230,
#   'totalCash': 53225201664,
#   'totalDebt': 116022796288,
#   'totalRevenue': 559329705984,
#   'totalCashPerShare': 184.532,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 1939.377,
#   'quickRatio': None,
#   'recommendationMean': 1.8,
#   'exchange': 'NSI',
#   'shortName': 'ULTRATECH CEMENT',
#   'longName': 'UltraTech Cement Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': True,
#   'gmtOffSetMilliseconds': '19800000',
#   'underlyingSymbol': None,
#   'quoteType': 'EQUITY',
#   'symbol': 'ULTRACEMCO.NS',
#   'underlyingExchangeSymbol': None,
#   'headSymbol': None,
#   'messageBoardId': 'finmb_13192517',
#   'uuid': 'ac3a92dd-3060-34f8-99b5-d2813b6f3672',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 3.487,
#   'beta3Year': None,
#   'enterpriseToEbitda': 17.232,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': 137.04,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 288456992,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 1412.932,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.22386,
#   'netIncomeToCommon': 70658400256,
#   'trailingEps': 242.217,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': 4.382978,
#   'heldPercentInsiders': 0.60785997,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 114883296,
#   'beta': 0.588358,
#   'enterpriseValue': 1950510350336,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.07,
#   'priceToSalesTrailing12Months': 3.2244735,
#   'dateShortInterest': None,
#   'pegRatio': None,
#   'ytdReturn': None,
#   'forwardPE': 45.190094,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 6177.1,
#   'regularMarketOpen': 6208,
#   'twoHundredDayAverage': 6518.9927,
#   'trailingAnnualDividendYield': 0.005989866,
#   'payoutRatio': 0.1511,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 6273.95,
#   'navPrice': None,
#   'averageDailyVolume10Day': 558433,
#   'regularMarketPreviousClose': 6177.1,
#   'fiftyDayAverage': 6548.246,
#   'trailingAnnualDividendRate': 37,
#   'open': 6208,
#   'averageVolume10days': 558433,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 38,
#   'exDividendDate': 1659398400,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 6128,
#   'currency': 'INR',
#   'trailingPE': 25.567364,
#   'regularMarketVolume': 467938,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 1803543773184,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 442806,
#   'dayLow': 6128,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 467938,
#   'fiftyTwoWeekHigh': 8269,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 0.31,
#   'fiftyTwoWeekLow': 5157.05,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0058,
#   'bidSize': 0,
#   'dayHigh': 6273.95,
#   'regularMarketPrice': 6192.85,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/ultratechcement.com'},
#  {'zip': '400051',
#   'sector': 'Basic Materials',
#   'fullTimeEmployees': 13054,
#   'longBusinessSummary': 'UPL Limited engages in the provision of sustainable agriculture products and solutions in India and internationally. It operates through two segments, Agro Activity and Non-Agro Activity. The company offers sorghum, forages, corn, canola, sunflower, vegetable, rice, wheat, soya, pearl millet, oats, alfalfa, bio-fumigants, and mustard seeds. It also provides herbicides; fungicides; insecticides and acaricides; seed treatment products; adjuvants; and ProNutiva, a solution for crop protection. In addition, the company offers plant stress and stimulation solutions; post-harvest products including coatings,\n cleaners, sanitisers, fungicides, growth regulators, and anti-scald; soil and water technologies; aquatic treatment solutions; and farmer advisory and education services, as well as farm services. Further, it produces and sells industrial chemicals, chemical intermediates, speciality chemicals and non agricultural related products. UPL Limited has a strategic collaboration with Chr. Hansen Holding A/S to develop microbial-based biosolutions. The company was formerly known as United Phosphorus Limited and changed its name to UPL Limited in October 2013. UPL Limited was founded in 1969 and is headquartered in Mumbai, India.',
#   'city': 'Mumbai',
#   'phone': '91 22 7152 8000',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.upl-ltd.com',
#   'maxAge': 1,
#   'address1': 'UPL House, 610 B/2',
#   'industry': 'Agricultural Inputs',
#   'address2': 'Bandra Village Off Western Express Highway Bandra (East)',
#   'ebitdaMargins': 0.2005,
#   'profitMargins': 0.07842,
#   'grossMargins': 0.51548,
#   'operatingCashflow': 64960000000,
#   'revenueGrowth': 0.24,
#   'operatingMargins': 0.16905001,
#   'ebitda': 92710002688,
#   'targetLowPrice': 624,
#   'recommendationKey': 'buy',
#   'grossProfits': 238360000000,
#   'freeCashflow': 17622499328,
#   'targetMedianPrice': 958,
#   'currentPrice': 677.7,
#   'earningsGrowth': 0.41,
#   'currentRatio': 1.409,
#   'returnOnAssets': 0.06382,
#   'numberOfAnalystOpinions': 26,
#   'targetMeanPrice': 939.31,
#   'debtToEquity': 91.132,
#   'returnOnEquity': 0.16466999,
#   'targetHighPrice': 1060,
#   'totalCash': 69149999104,
#   'totalDebt': 267090001920,
#   'totalRevenue': 462399995904,
#   'totalCashPerShare': 90.505,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 605.2,
#   'quickRatio': 0.888,
#   'recommendationMean': 1.8,
#   'exchange': 'NSI',
#   'shortName': 'UPL LIMITED',
#   'longName': 'UPL Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': True,
#   'gmtOffSetMilliseconds': '19800000',
#   'underlyingSymbol': None,
#   'quoteType': 'EQUITY',
#   'symbol': 'UPL.NS',
#   'underlyingExchangeSymbol': None,
#   'headSymbol': None,
#   'messageBoardId': 'finmb_20376936',
#   'uuid': 'e2080cbb-d21c-3bb2-9b38-6fec3b132fef',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 1.753,
#   'beta3Year': None,
#   'enterpriseToEbitda': 8.744,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': 47.28,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 764044992,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 249.237,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.43744,
#   'netIncomeToCommon': 35050000384,
#   'trailingEps': 31.735,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': 2.7190988,
#   'heldPercentInsiders': 0.29279,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 542159015,
#   'beta': 0.994974,
#   'enterpriseValue': 810644078592,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1562025600,
#   'lastSplitFactor': '3:2',
#   'legalType': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.297,
#   'priceToSalesTrailing12Months': 1.1197952,
#   'dateShortInterest': None,
#   'pegRatio': 0.92,
#   'ytdReturn': None,
#   'forwardPE': 14.333757,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 679.9,
#   'regularMarketOpen': 683.3,
#   'twoHundredDayAverage': 751.6132,
#   'trailingAnnualDividendYield': 0.014708045,
#   'payoutRatio': 0.218,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 687.85,
#   'navPrice': None,
#   'averageDailyVolume10Day': 2480849,
#   'regularMarketPreviousClose': 679.9,
#   'fiftyDayAverage': 742.769,
#   'trailingAnnualDividendRate': 10,
#   'open': 683.3,
#   'averageVolume10days': 2480849,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 10,
#   'exDividendDate': 1658880000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 672.5,
#   'currency': 'INR',
#   'trailingPE': 21.35497,
#   'regularMarketVolume': 1199618,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 517793284096,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 2421201,
#   'dayLow': 672.5,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 1199618,
#   'fiftyTwoWeekHigh': 848,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 607.5,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0135,
#   'bidSize': 0,
#   'dayHigh': 687.85,
#   'regularMarketPrice': 677.7,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/upl-ltd.com'},
#  {'zip': '560035',
#   'sector': 'Technology',
#   'fullTimeEmployees': 258574,
#   'longBusinessSummary': 'Wipro Limited operates as information technology (IT), consulting, and business process services company worldwide. It operates through three segments: IT Services, IT Products, and India State Run Enterprise Services (ISRE). The IT Services segment offers IT and IT-enabled services, including digital strategy advisory, customer-centric design, technology and IT consulting, custom application design, development, re-engineering and maintenance, systems integration, package implementation, cloud and infrastructure, business process, cloud, mobility and analytics, research and development, and hardware and software design services to enterprises. It serves customers in various industry sectors, such as healthcare and medical devices, consumer goods and life sciences, retail, transportation and services, communications, media and information services, technology products and platforms, banking, financial services and insurance, manufacturing, hi-tech, energy, and utilities. The IT Products segment provides a range of third-party IT products comprising enterprise platforms, networking solutions, software and data storage products, contact center infrastructure, enterprise security, IT optimization technologies, video solutions, and end-user computing solutions. It serves enterprises in various industries primarily in the India market, which comprise the government, defense, IT and IT-enabled services, telecommunications, manufacturing, utilities, education, and financial services sectors. The ISRE segment offers IT services to entities and departments owned or controlled by the Government of India and/or various Indian State Governments. The company was incorporated in 1945 and is based in Bengaluru, India.',
#   'city': 'Bengaluru',
#   'phone': '91 80 2844 0011',
#   'country': 'India',
#   'companyOfficers': [],
#   'website': 'https://www.wipro.com',
#   'maxAge': 1,
#   'address1': 'Doddakannelli',
#   'fax': '91 80 2844 0254',
#   'industry': 'Information Technology Services',
#   'address2': 'Sarjapur Road',
#   'ebitdaMargins': 0.19049999,
#   'profitMargins': 0.14023,
#   'grossMargins': 0.29111,
#   'operatingCashflow': 79050997760,
#   'revenueGrowth': 0.179,
#   'operatingMargins': 0.16184,
#   'ebitda': 156918005760,
#   'targetLowPrice': 200,
#   'recommendationKey': 'underperform',
#   'grossProfits': 225904000000,
#   'freeCashflow': 33567125504,
#   'targetMedianPrice': 290,
#   'currentPrice': 398.4,
#   'earningsGrowth': -0.208,
#   'currentRatio': 1.947,
#   'returnOnAssets': 0.08191,
#   'numberOfAnalystOpinions': 41,
#   'targetMeanPrice': 290.68,
#   'debtToEquity': 28.79,
#   'returnOnEquity': 0.18080999,
#   'targetHighPrice': 365,
#   'totalCash': 308734984192,
#   'totalDebt': 197877006336,
#   'totalRevenue': 823696031744,
#   'totalCashPerShare': 56.458,
#   'financialCurrency': 'INR',
#   'revenuePerShare': 150.617,
#   'quickRatio': 1.798,
#   'recommendationMean': 3.7,
#   'exchange': 'NSI',
#   'shortName': 'WIPRO LTD',
#   'longName': 'Wipro Limited',
#   'exchangeTimezoneName': 'Asia/Kolkata',
#   'exchangeTimezoneShortName': 'IST',
#   'isEsgPopulated': True,
#   'gmtOffSetMilliseconds': '19800000',
#   'underlyingSymbol': None,
#   'quoteType': 'EQUITY',
#   'symbol': 'WIPRO.NS',
#   'underlyingExchangeSymbol': None,
#   'headSymbol': None,
#   'messageBoardId': 'finmb_598611',
#   'uuid': '9b2184f0-c004-3a57-8738-9263da046c6c',
#   'market': 'in_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 2.679,
#   'beta3Year': None,
#   'enterpriseToEbitda': 14.062,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': 19.55,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 5463830016,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 100.374,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1648684800,
#   'heldPercentInstitutions': 0.14114,
#   'netIncomeToCommon': 115506003968,
#   'trailingEps': 19.07,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': 3.9691553,
#   'heldPercentInsiders': 0.73343,
#   'nextFiscalYearEnd': 1711843200,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 1483403951,
#   'beta': 0.797319,
#   'enterpriseValue': 2206504058880,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1551830400,
#   'lastSplitFactor': '4:3',
#   'legalType': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.207,
#   'priceToSalesTrailing12Months': 2.6427102,
#   'dateShortInterest': None,
#   'pegRatio': 2.16,
#   'ytdReturn': None,
#   'forwardPE': 20.378517,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 394.8,
#   'regularMarketOpen': 396.8,
#   'twoHundredDayAverage': 511.21725,
#   'trailingAnnualDividendYield': 0.0025329283,
#   'payoutRatio': 0.2849,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 401.4,
#   'navPrice': None,
#   'averageDailyVolume10Day': 7457519,
#   'regularMarketPreviousClose': 394.8,
#   'fiftyDayAverage': 417.802,
#   'trailingAnnualDividendRate': 1,
#   'open': 396.8,
#   'averageVolume10days': 7457519,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 20,
#   'exDividendDate': 1649116800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 392,
#   'currency': 'INR',
#   'trailingPE': 20.891453,
#   'regularMarketVolume': 6224811,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 2176789905408,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 7032852,
#   'dayLow': 392,
#   'ask': 0,
#   'askSize': 0,
#   'volume': 6224811,
#   'fiftyTwoWeekHigh': 739.85,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 0.4,
#   'fiftyTwoWeekLow': 384.6,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.047199998,
#   'bidSize': 0,
#   'dayHigh': 401.4,
#   'regularMarketPrice': 398.4,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/wipro.com'}]

# %%
#Saving data in a dataframe
df = pd.DataFrame(infos)
df
# Out:
#        zip                  sector  fullTimeEmployees  \
# 0   382421             Industrials             2736.0
# 1   600006              Healthcare            71113.0
# 2   400055         Basic Materials             7423.0
# 3   400025      Financial Services            86400.0
# 4   411035       Consumer Cyclical            10134.0
# 5   411014      Financial Services            35425.0
# 6   411014      Financial Services            59961.0
# 7   110070  Communication Services            18000.0
# 8   400001                  Energy             8594.0
# 9   560048      Consumer Defensive             4467.0
# 10  400013              Healthcare            25927.0
# 11  700156                  Energy           248550.0
# 12  500032              Healthcare            16543.0
# 13  500034              Healthcare            24795.0
# 14  122001       Consumer Cyclical             4739.0
# 15  400030         Basic Materials            23591.0
# 16  201304              Technology           210966.0
# 17  400020      Financial Services             3599.0
# 18  400013      Financial Services           152511.0
# 19  400011      Financial Services            22059.0
# 20  110070       Consumer Cyclical             9173.0
# 21  400030         Basic Materials            35869.0
# 22  400099      Consumer Defensive            21000.0
# 23  400051      Financial Services                NaN
# 24  400013      Financial Services            33582.0
# 25  560100              Technology           335186.0
# 26  700071      Consumer Defensive            23829.0
# 27  400051         Basic Materials            13483.0
# 28  400051      Financial Services            90000.0
# 29  400001             Industrials            49921.0
# 30  400018       Consumer Cyclical           260000.0
# 31  110070       Consumer Cyclical                NaN
# 32  122002      Consumer Defensive             7910.0
# 33  110003               Utilities                NaN
# 34  110070                  Energy                NaN
# 35  122001               Utilities                NaN
# 36  400021                  Energy           236334.0
# 37  400021      Financial Services           244250.0
# 38  400069      Financial Services            18401.0
# 39  700001         Basic Materials             6445.0
# 40  400063              Healthcare                NaN
# 41  400018       Consumer Cyclical            73608.0
# 42  400001         Basic Materials            65000.0
# 43  400001              Technology           606331.0
# 44  400001      Consumer Defensive             2932.0
# 45  411057              Technology           158035.0
# 46  560100       Consumer Cyclical             7263.0
# 47  400093         Basic Materials            21942.0
# 48  400051         Basic Materials            13054.0
# 49  560035              Technology           258574.0
#
#                                   longBusinessSummary       city  \
# 0   Adani Ports and Special Economic Zone Limited,...  Ahmedabad
# 1   Apollo Hospitals Enterprise Limited, together ...    Chennai
# 2   Asian Paints Limited, together with its subsid...     Mumbai
# 3   Axis Bank Limited provides various financial p...     Mumbai
# 4   Bajaj Auto Limited develops, manufactures, and...       Pune
# 5   Bajaj Finance Limited operates as a non-bankin...       Pune
# 6   Bajaj Finserv Ltd., through its subsidiaries, ...       Pune
# 7   Bharti Airtel Limited operates as a telecommun...  New Delhi
# 8   Bharat Petroleum Corporation Limited refines c...     Mumbai
# 9   Britannia Industries Limited manufactures and ...  Bengaluru
# 10  Cipla Limited, together with its subsidiaries,...     Mumbai
# 11  Coal India Limited, together with its subsidia...    Kolkata
# 12  Divi's Laboratories Limited manufactures and s...  Hyderabad
# 13  Dr. Reddy's Laboratories Limited, together wit...  Hyderabad
# 14  Eicher Motors Limited, an automobile company, ...   Gurugram
# 15  Grasim Industries Limited operates in fibre, y...     Mumbai
# 16  HCL Technologies Limited offers software devel...      Noida
# 17  Housing Development Finance Corporation Limite...     Mumbai
# 18  HDFC Bank Limited provides banking and financi...     Mumbai
# 19  HDFC Life Insurance Company Limited provides i...     Mumbai
# 20  Hero MotoCorp Limited manufactures and sells m...  New Delhi
# 21  Hindalco Industries Limited, together with its...     Mumbai
# 22  Hindustan Unilever Limited, a consumer goods c...     Mumbai
# 23  ICICI Bank Limited provides various banking pr...     Mumbai
# 24  IndusInd Bank Limited provides various banking...     Mumbai
# 25  Infosys Limited, together with its subsidiarie...  Bengaluru
# 26  ITC Limited engages in the fast-moving consume...    Kolkata
# 27  JSW Steel Limited engages in the manufacture a...     Mumbai
# 28  Kotak Mahindra Bank Limited, provides banking ...     Mumbai
# 29  Larsen & Toubro Limited engages in engineering...     Mumbai
# 30  Mahindra & Mahindra Limited provides mobility ...     Mumbai
# 31  Maruti Suzuki India Limited manufactures, purc...  New Delhi
# 32  Nestlé India Limited manufactures and sells fo...   Gurugram
# 33  NTPC Limited generates and sells bulk power to...  New Delhi
# 34  Oil and Natural Gas Corporation Limited explor...  New Delhi
# 35  Power Grid Corporation of India Limited, a cen...   Gurugram
# 36  Reliance Industries Limited engages in hydroca...     Mumbai
# 37  State Bank of India provides various banking p...     Mumbai
# 38  SBI Life Insurance Company Limited operates as...     Mumbai
# 39  Shree Cement Limited manufactures and sells ce...    Kolkata
# 40  Sun Pharmaceutical Industries Limited, a gener...     Mumbai
# 41  Tata Motors Limited designs, develops, manufac...     Mumbai
# 42  Tata Steel Limited manufactures and distribute...     Mumbai
# 43  Tata Consultancy Services Limited provides inf...     Mumbai
# 44  Tata Consumer Products Limited, together with ...     Mumbai
# 45  Tech Mahindra Limited provides information tec...       Pune
# 46  Titan Company Limited, together with its subsi...  Bengaluru
# 47  UltraTech Cement Limited, together with its su...     Mumbai
# 48  UPL Limited engages in the provision of sustai...     Mumbai
# 49  Wipro Limited operates as information technolo...  Bengaluru
#
#               phone country companyOfficers  \
# 0   91 79 2656 5555   India              []
# 1               NaN   India              []
# 2   91 22 6218 1000   India              []
# 3   91 22 2425 2525   India              []
# 4   91 20 2747 2851   India              []
# 5   91 20 7157 6403   India              []
# 6   91 20 7157 6064   India              []
# 7   91 11 4666 6100   India              []
# 8   91 22 2271 3000   India              []
# 9   91 80 3768 7100   India              []
# 10  91 22 2482 6000   India              []
# 11  91 33 2324 5555   India              []
# 12  91 40 6696 6300   India              []
# 13  91 40 4900 2900   India              []
# 14  91 12 4441 5600   India              []
# 15  91 22 6652 5000   India              []
# 16  91 11 2643 6336   India              []
# 17  91 22 6631 6000   India              []
# 18  91 22 6652 1000   India              []
# 19  91 22 6751 6666   India              []
# 20  91 11 4604 4220   India              []
# 21  91 22 6662 6666   India              []
# 22  91 22 5043 3000   India              []
# 23  91 22 2653 1414   India              []
# 24  91 22 2423 1999   India              []
# 25  91 80 2852 0261   India              []
# 26  91 33 2288 9371   India              []
# 27  91 22 4286 1000   India              []
# 28  91 22 6166 0001   India              []
# 29  91 22 6752 5656   India              []
# 30  91 22 2490 1441   India              []
# 31  91 11 4678 1000   India              []
# 32  91 12 4394 0000   India              []
# 33  91 11 2438 7333   India              []
# 34  91 11 2675 4073   India              []
# 35  91 12 4282 2000   India              []
# 36  91 22 3555 5000   India              []
# 37  91 22 2274 0841   India              []
# 38  91 22 6191 0000   India              []
# 39  91 33 2230 9601   India              []
# 40  91 22 4324 4324   India              []
# 41  91 22 6757 7200   India              []
# 42  91 22 6665 8282   India              []
# 43  91 22 6778 9595   India              []
# 44  91 22 6121 8400   India              []
# 45  91 20 4225 0000   India              []
# 46  91 80 6704 7000   India              []
# 47  91 22 6691 7800   India              []
# 48  91 22 7152 8000   India              []
# 49  91 80 2844 0011   India              []
#
#                                               website  maxAge  ...   dayHigh  \
# 0                          https://www.adaniports.com       1  ...    875.00
# 1                     https://www.apollohospitals.com       1  ...   4354.10
# 2                         https://www.asianpaints.com       1  ...   3500.00
# 3                            https://www.axisbank.com       1  ...    754.15
# 4                           https://www.bajajauto.com       1  ...   3594.95
# 5   https://www.bajajfinserv.in/corporate-bajaj-fi...       1  ...   7379.95
# 6   https://www.bajajfinserv.in/corporate-bajaj-fi...       1  ...   1715.75
# 7                               https://www.airtel.in       1  ...    765.00
# 8                      https://www.bharatpetroleum.in       1  ...    312.00
# 9                             https://britannia.co.in       1  ...   3889.80
# 10                              https://www.cipla.com       1  ...   1104.90
# 11                           https://www.coalindia.in       1  ...    219.70
# 12                          https://www.divislabs.com       1  ...   3712.00
# 13                           https://www.drreddys.com       1  ...   4200.00
# 14                       https://www.eichermotors.com       1  ...   3615.00
# 15                             https://www.grasim.com       1  ...   1696.95
# 16                            https://www.hcltech.com       1  ...    921.45
# 17                               https://www.hdfc.com       1  ...   2323.90
# 18                           https://www.hdfcbank.com       1  ...   1440.00
# 19                           https://www.hdfclife.com       1  ...    526.90
# 20                       https://www.heromotocorp.com       1  ...   2735.00
# 21                           https://www.hindalco.com       1  ...    379.95
# 22                              https://www.hul.co.in       1  ...   2713.75
# 23                          https://www.icicibank.com       1  ...    874.85
# 24                           https://www.indusind.com       1  ...   1178.00
# 25                            https://www.infosys.com       1  ...   1406.50
# 26                          https://www.itcportal.com       1  ...    339.55
# 27                                 https://www.jsw.in       1  ...    650.95
# 28                              https://www.kotak.com       1  ...   1834.85
# 29                       https://www.larsentoubro.com       1  ...   1864.00
# 30                           https://www.mahindra.com       1  ...   1252.90
# 31                       https://www.marutisuzuki.com       1  ...   8908.95
# 32                              https://www.nestle.in       1  ...  18795.00
# 33                             https://www.ntpc.co.in       1  ...    161.65
# 34                          https://www.ongcindia.com       1  ...    127.90
# 35                           https://www.powergrid.in       1  ...    207.90
# 36                                https://www.ril.com       1  ...   2426.00
# 37                              https://www.sbi.co.in       1  ...    550.90
# 38                          https://www.sbilife.co.in       1  ...   1270.65
# 39                        https://www.shreecement.com       1  ...  21483.70
# 40                          https://www.sunpharma.com       1  ...    909.85
# 41                         https://www.tatamotors.com       1  ...    404.00
# 42                          https://www.tatasteel.com       1  ...    101.35
# 43                                https://www.tcs.com       1  ...   3025.00
# 44                       https://www.tataconsumer.com       1  ...    801.40
# 45                       https://www.techmahindra.com       1  ...   1045.00
# 46                        https://www.titancompany.in       1  ...   2679.55
# 47                    https://www.ultratechcement.com       1  ...   6273.95
# 48                            https://www.upl-ltd.com       1  ...    687.85
# 49                              https://www.wipro.com       1  ...    401.40
#
#    coinMarketCapLink regularMarketPrice preMarketPrice  \
# 0                NaN             844.20           None
# 1                NaN            4242.95           None
# 2                NaN            3470.65           None
# 3                NaN             737.50           None
# 4                NaN            3541.90           None
# 5                NaN            7242.85           None
# 6                NaN            1679.55           None
# 7                NaN             760.60           None
# 8                NaN             310.65           None
# 9                NaN            3824.15           None
# 10               NaN            1098.70           None
# 11               NaN             213.90           None
# 12               NaN            3680.20           None
# 13               NaN            4181.60           None
# 14               NaN            3570.55           None
# 15               NaN            1682.50           None
# 16               NaN             918.75           None
# 17               NaN            2289.15           None
# 18               NaN            1413.85           None
# 19               NaN             520.85           None
# 20               NaN            2638.25           None
# 21               NaN             373.60           None
# 22               NaN            2679.25           None
# 23               NaN             852.55           None
# 24               NaN            1165.10           None
# 25               NaN            1393.55           None
# 26               NaN             334.85           None
# 27               NaN             637.00           None
# 28               NaN            1799.30           None
# 29               NaN            1841.20           None
# 30               NaN            1235.75           None
# 31               NaN            8774.05           None
# 32               NaN           18672.65           None
# 33               NaN             159.00           None
# 34               NaN             124.45           None
# 35               NaN             204.85           None
# 36               NaN            2396.25           None
# 37               NaN             536.50           None
# 38               NaN            1242.30           None
# 39               NaN           21163.25           None
# 40               NaN             897.15           None
# 41               NaN             398.80           None
# 42               NaN              97.65           None
# 43               NaN            3017.45           None
# 44               NaN             797.85           None
# 45               NaN            1022.50           None
# 46               NaN            2600.35           None
# 47               NaN            6192.85           None
# 48               NaN             677.70           None
# 49               NaN             398.40           None
#
#                                          logo_url  trailingPegRatio  \
# 0        https://logo.clearbit.com/adaniports.com               NaN
# 1   https://logo.clearbit.com/apollohospitals.com               NaN
# 2       https://logo.clearbit.com/asianpaints.com               NaN
# 3          https://logo.clearbit.com/axisbank.com               NaN
# 4         https://logo.clearbit.com/bajajauto.com               NaN
# 5       https://logo.clearbit.com/bajajfinserv.in               NaN
# 6       https://logo.clearbit.com/bajajfinserv.in               NaN
# 7             https://logo.clearbit.com/airtel.in               NaN
# 8    https://logo.clearbit.com/bharatpetroleum.in               NaN
# 9       https://logo.clearbit.com/britannia.co.in               NaN
# 10            https://logo.clearbit.com/cipla.com               NaN
# 11         https://logo.clearbit.com/coalindia.in               NaN
# 12        https://logo.clearbit.com/divislabs.com               NaN
# 13         https://logo.clearbit.com/drreddys.com            1.1776
# 14     https://logo.clearbit.com/eichermotors.com               NaN
# 15           https://logo.clearbit.com/grasim.com               NaN
# 16          https://logo.clearbit.com/hcltech.com               NaN
# 17             https://logo.clearbit.com/hdfc.com               NaN
# 18         https://logo.clearbit.com/hdfcbank.com               NaN
# 19         https://logo.clearbit.com/hdfclife.com               NaN
# 20     https://logo.clearbit.com/heromotocorp.com               NaN
# 21         https://logo.clearbit.com/hindalco.com               NaN
# 22            https://logo.clearbit.com/hul.co.in               NaN
# 23        https://logo.clearbit.com/icicibank.com               NaN
# 24         https://logo.clearbit.com/indusind.com               NaN
# 25          https://logo.clearbit.com/infosys.com               NaN
# 26        https://logo.clearbit.com/itcportal.com               NaN
# 27               https://logo.clearbit.com/jsw.in               NaN
# 28            https://logo.clearbit.com/kotak.com               NaN
# 29     https://logo.clearbit.com/larsentoubro.com               NaN
# 30         https://logo.clearbit.com/mahindra.com               NaN
# 31     https://logo.clearbit.com/marutisuzuki.com               NaN
# 32            https://logo.clearbit.com/nestle.in               NaN
# 33           https://logo.clearbit.com/ntpc.co.in               NaN
# 34        https://logo.clearbit.com/ongcindia.com               NaN
# 35         https://logo.clearbit.com/powergrid.in               NaN
# 36              https://logo.clearbit.com/ril.com               NaN
# 37            https://logo.clearbit.com/sbi.co.in               NaN
# 38        https://logo.clearbit.com/sbilife.co.in               NaN
# 39      https://logo.clearbit.com/shreecement.com               NaN
# 40        https://logo.clearbit.com/sunpharma.com               NaN
# 41       https://logo.clearbit.com/tatamotors.com               NaN
# 42        https://logo.clearbit.com/tatasteel.com               NaN
# 43              https://logo.clearbit.com/tcs.com               NaN
# 44     https://logo.clearbit.com/tataconsumer.com               NaN
# 45     https://logo.clearbit.com/techmahindra.com               NaN
# 46      https://logo.clearbit.com/titancompany.in               NaN
# 47  https://logo.clearbit.com/ultratechcement.com               NaN
# 48          https://logo.clearbit.com/upl-ltd.com               NaN
# 49            https://logo.clearbit.com/wipro.com               NaN
#
#     underlyingSymbol  underlyingExchangeSymbol  headSymbol  \
# 0                NaN                       NaN         NaN
# 1                NaN                       NaN         NaN
# 2                NaN                       NaN         NaN
# 3                NaN                       NaN         NaN
# 4                NaN                       NaN         NaN
# 5                NaN                       NaN         NaN
# 6                NaN                       NaN         NaN
# 7                NaN                       NaN         NaN
# 8                NaN                       NaN         NaN
# 9                NaN                       NaN         NaN
# 10               NaN                       NaN         NaN
# 11               NaN                       NaN         NaN
# 12               NaN                       NaN         NaN
# 13               NaN                       NaN         NaN
# 14               NaN                       NaN         NaN
# 15               NaN                       NaN         NaN
# 16               NaN                       NaN         NaN
# 17               NaN                       NaN         NaN
# 18               NaN                       NaN         NaN
# 19               NaN                       NaN         NaN
# 20               NaN                       NaN         NaN
# 21               NaN                       NaN         NaN
# 22               NaN                       NaN         NaN
# 23               NaN                       NaN         NaN
# 24               NaN                       NaN         NaN
# 25               NaN                       NaN         NaN
# 26               NaN                       NaN         NaN
# 27               NaN                       NaN         NaN
# 28               NaN                       NaN         NaN
# 29               NaN                       NaN         NaN
# 30               NaN                       NaN         NaN
# 31               NaN                       NaN         NaN
# 32               NaN                       NaN         NaN
# 33               NaN                       NaN         NaN
# 34               NaN                       NaN         NaN
# 35               NaN                       NaN         NaN
# 36               NaN                       NaN         NaN
# 37               NaN                       NaN         NaN
# 38               NaN                       NaN         NaN
# 39               NaN                       NaN         NaN
# 40               NaN                       NaN         NaN
# 41               NaN                       NaN         NaN
# 42               NaN                       NaN         NaN
# 43               NaN                       NaN         NaN
# 44               NaN                       NaN         NaN
# 45               NaN                       NaN         NaN
# 46               NaN                       NaN         NaN
# 47               NaN                       NaN         NaN
# 48               NaN                       NaN         NaN
# 49               NaN                       NaN         NaN
#
#                                     uuid
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22  b9a3be7e-e399-3e49-b6b7-ed2d603368eb
# 23  d21a6484-0aac-330e-a9d9-9718a5f952f0
# 24  9781daee-0bea-3be5-a327-74d3f4bfb8e7
# 25  6e0e3969-0bf9-3676-8a5c-d91501277ca6
# 26  2d1c10cc-4829-3114-aea5-57a0600cb464
# 27  266ea77e-9e0c-34f3-97a6-fc70e087818c
# 28  e9b8d17b-5451-3759-a200-d6130e6b96d7
# 29  51a5c7d9-eafd-371d-afd4-cad7e0dbbd48
# 30  08f0f1eb-593a-354a-a5bd-38231342ca8a
# 31  2b186ade-01ba-3c85-b686-b892dbd32072
# 32  12d28da0-1b60-3bd0-9b1f-2bb8edb342e9
# 33  8ba23af1-4242-3e1c-8797-3049e46b897c
# 34  4bbe7a6f-a7cd-39fe-bc9a-e211fb881c45
# 35  304a81d9-2610-307c-99cf-d548f87634cb
# 36  6fb3aba7-25b9-3826-85a7-5fb8a94f4e84
# 37  f8326bb6-61ba-333c-a8c6-52d3a1bf3c06
# 38  9623c870-f343-3ce2-8f67-2ee8d552ff38
# 39  7fa9f112-2d77-37a2-b40d-8924292b4775
# 40  aaf5d89c-04c2-30f3-b8ab-32d98e120d78
# 41  ddba5579-685b-35a6-8ca9-fdc0ae8f12f6
# 42  fadf0ed1-ada5-3bab-993c-4f6b06474dd3
# 43  cc4c841e-ad42-3fdb-8d9f-b26fa8acd1cf
# 44  95870c70-07ec-33af-a4e3-6c8e057f1afd
# 45  99084168-d40f-3aaa-a5c8-3d92f955df00
# 46  e0b199f6-7ef1-3919-a462-9165d47a615e
# 47  ac3a92dd-3060-34f8-99b5-d2813b6f3672
# 48  e2080cbb-d21c-3bb2-9b38-6fec3b132fef
# 49  9b2184f0-c004-3a57-8738-9263da046c6c
#
# [50 rows x 159 columns]

# %%
#Removing columns with error
df = df.drop(columns = "companyOfficers")

# %%
#Downloading last 1 year share price information of all symbols 
df2 = yf.download(nifty_symbols, period='1y', group_by = 'tickers')
df2
# Out:
# [*********************100%***********************]  50 of 50 completed
#             NESTLEIND.NS                                            \
#                     Open          High           Low         Close
# Date
# 2021-09-28  19690.000000  19718.650391  19459.050781  19544.750000
# 2021-09-29  19544.750000  19700.000000  19421.650391  19506.750000
# 2021-09-30  19478.300781  19589.949219  19316.150391  19445.550781
# 2021-10-01  19445.000000  19644.949219  19252.050781  19549.949219
# 2021-10-04  19549.949219  19650.000000  19362.050781  19492.949219
# ...                  ...           ...           ...           ...
# 2022-09-20  18810.000000  18920.000000  18575.099609  18616.650391
# 2022-09-21  18616.000000  18889.400391  18591.050781  18649.900391
# 2022-09-22  18649.900391  18835.000000  18580.550781  18638.300781
# 2022-09-23  18591.000000  18656.199219  18450.050781  18495.900391
# 2022-09-26  18495.800781  18889.900391  18397.550781  18453.300781
#
#                                       UPL.NS                          \
#                Adj Close  Volume        Open        High         Low
# Date
# 2021-09-28  19429.757812   57686  728.000000  732.900024  710.250000
# 2021-09-29  19391.982422   46295  711.900024  722.900024  709.000000
# 2021-09-30  19331.142578   44373  717.150024  719.900024  706.150024
# 2021-10-01  19434.927734   39869  707.000000  714.049988  698.250000
# 2021-10-04  19378.261719   32796  713.099976  719.900024  694.000000
# ...                  ...     ...         ...         ...         ...
# 2022-09-20  18616.650391   83800  715.849976  723.599976  714.200012
# 2022-09-21  18649.900391   46299  717.000000  724.450012  705.000000
# 2022-09-22  18638.300781   77931  709.099976  726.599976  709.099976
# 2022-09-23  18495.900391   35842  724.000000  727.299988  700.000000
# 2022-09-26  18453.300781  113085  698.000000  701.950012  670.400024
#
#                         ... HINDALCO.NS                                    \
#                  Close  ...         Low       Close   Adj Close    Volume
# Date                    ...
# 2021-09-28  716.799988  ...  475.049988  478.149994  478.149994   6148679
# 2021-09-29  717.150024  ...  473.399994  494.149994  494.149994   9508220
# 2021-09-30  707.700012  ...  485.600006  487.950012  487.950012  14333358
# 2021-10-01  712.650024  ...  473.450012  484.350006  484.350006   8072310
# 2021-10-04  702.950012  ...  481.000000  505.700012  505.700012  10303925
# ...                ...  ...         ...         ...         ...       ...
# 2022-09-20  719.900024  ...  415.799988  421.450012  421.450012   8758050
# 2022-09-21  717.500000  ...  410.799988  411.350006  411.350006   6859320
# 2022-09-22  721.349976  ...  403.500000  412.100006  412.100006   8704463
# 2022-09-23  702.849976  ...  394.450012  396.350006  396.350006   9228856
# 2022-09-26  679.900024  ...  369.600006  373.399994  373.399994  13092570
#
#                 ITC.NS                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 2021-09-28  239.850006  241.600006  236.300003  237.750000  232.380295
# 2021-09-29  236.000000  241.399994  235.699997  238.100006  232.722397
# 2021-09-30  239.899994  240.399994  235.250000  236.149994  230.816422
# 2021-10-01  235.199997  237.000000  232.899994  235.350006  230.034500
# 2021-10-04  236.000000  238.350006  235.399994  236.600006  231.256271
# ...                ...         ...         ...         ...         ...
# 2022-09-20  338.750000  339.600006  335.000000  336.000000  336.000000
# 2022-09-21  336.000000  345.200012  335.500000  340.950012  340.950012
# 2022-09-22  341.000000  348.750000  340.899994  345.049988  345.049988
# 2022-09-23  347.500000  349.549988  343.299988  346.399994  346.399994
# 2022-09-26  344.850006  345.950012  331.750000  332.600006  332.600006
#
#
#               Volume
# Date
# 2021-09-28  15713947
# 2021-09-29  15450046
# 2021-09-30  16357902
# 2021-10-01  15956143
# 2021-10-04  10686552
# ...              ...
# 2022-09-20   9526068
# 2022-09-21  20992080
# 2022-09-22  24179987
# 2022-09-23  22838807
# 2022-09-26  16205789
#
# [248 rows x 300 columns]

# %%
#Adding index column
df2 = df2.reset_index()
df2
# Out:
#           Date  NESTLEIND.NS                                            \
#                         Open          High           Low         Close
# 0   2021-09-28  19690.000000  19718.650391  19459.050781  19544.750000
# 1   2021-09-29  19544.750000  19700.000000  19421.650391  19506.750000
# 2   2021-09-30  19478.300781  19589.949219  19316.150391  19445.550781
# 3   2021-10-01  19445.000000  19644.949219  19252.050781  19549.949219
# 4   2021-10-04  19549.949219  19650.000000  19362.050781  19492.949219
# ..         ...           ...           ...           ...           ...
# 243 2022-09-20  18810.000000  18920.000000  18575.099609  18616.650391
# 244 2022-09-21  18616.000000  18889.400391  18591.050781  18649.900391
# 245 2022-09-22  18649.900391  18835.000000  18580.550781  18638.300781
# 246 2022-09-23  18591.000000  18656.199219  18450.050781  18495.900391
# 247 2022-09-26  18495.800781  18889.900391  18397.550781  18453.300781
#
#                                UPL.NS                          ...  \
#         Adj Close  Volume        Open        High         Low  ...
# 0    19429.757812   57686  728.000000  732.900024  710.250000  ...
# 1    19391.982422   46295  711.900024  722.900024  709.000000  ...
# 2    19331.142578   44373  717.150024  719.900024  706.150024  ...
# 3    19434.927734   39869  707.000000  714.049988  698.250000  ...
# 4    19378.261719   32796  713.099976  719.900024  694.000000  ...
# ..            ...     ...         ...         ...         ...  ...
# 243  18616.650391   83800  715.849976  723.599976  714.200012  ...
# 244  18649.900391   46299  717.000000  724.450012  705.000000  ...
# 245  18638.300781   77931  709.099976  726.599976  709.099976  ...
# 246  18495.900391   35842  724.000000  727.299988  700.000000  ...
# 247  18453.300781  113085  698.000000  701.950012  670.400024  ...
#
#     HINDALCO.NS                                        ITC.NS              \
#             Low       Close   Adj Close    Volume        Open        High
# 0    475.049988  478.149994  478.149994   6148679  239.850006  241.600006
# 1    473.399994  494.149994  494.149994   9508220  236.000000  241.399994
# 2    485.600006  487.950012  487.950012  14333358  239.899994  240.399994
# 3    473.450012  484.350006  484.350006   8072310  235.199997  237.000000
# 4    481.000000  505.700012  505.700012  10303925  236.000000  238.350006
# ..          ...         ...         ...       ...         ...         ...
# 243  415.799988  421.450012  421.450012   8758050  338.750000  339.600006
# 244  410.799988  411.350006  411.350006   6859320  336.000000  345.200012
# 245  403.500000  412.100006  412.100006   8704463  341.000000  348.750000
# 246  394.450012  396.350006  396.350006   9228856  347.500000  349.549988
# 247  369.600006  373.399994  373.399994  13092570  344.850006  345.950012
#
#
#             Low       Close   Adj Close    Volume
# 0    236.300003  237.750000  232.380295  15713947
# 1    235.699997  238.100006  232.722397  15450046
# 2    235.250000  236.149994  230.816422  16357902
# 3    232.899994  235.350006  230.034500  15956143
# 4    235.399994  236.600006  231.256271  10686552
# ..          ...         ...         ...       ...
# 243  335.000000  336.000000  336.000000   9526068
# 244  335.500000  340.950012  340.950012  20992080
# 245  340.899994  345.049988  345.049988  24179987
# 246  343.299988  346.399994  346.399994  22838807
# 247  331.750000  332.600006  332.600006  16205789
#
# [248 rows x 301 columns]

# %%
#Using sqlalchemy to create a database in MySQL
mysql_engine = create_engine("mysql://root:Nav!2882@localhost:3306/stocksdb")

# %%
#Saving dataframe into SQL database
df.to_sql('info_table', mysql_engine)

# %%
df2.to_sql('stockprice_table', mysql_engine)

# %%
#Reading data that is loaded into the SQL database
pd.read_sql("select * from info_table", mysql_engine)
# Out:
#     index     zip                  sector  fullTimeEmployees  \
# 0       0  382421             Industrials             2736.0
# 1       1  600006              Healthcare            71113.0
# 2       2  400055         Basic Materials             7423.0
# 3       3  400025      Financial Services            86400.0
# 4       4  411035       Consumer Cyclical            10134.0
# 5       5  411014      Financial Services            35425.0
# 6       6  411014      Financial Services            59961.0
# 7       7  110070  Communication Services            18000.0
# 8       8  400001                  Energy             8594.0
# 9       9  560048      Consumer Defensive             4467.0
# 10     10  400013              Healthcare            25927.0
# 11     11  700156                  Energy           248550.0
# 12     12  500032              Healthcare            16543.0
# 13     13  500034              Healthcare            24795.0
# 14     14  122001       Consumer Cyclical             4739.0
# 15     15  400030         Basic Materials            23591.0
# 16     16  201304              Technology           210966.0
# 17     17  400020      Financial Services             3599.0
# 18     18  400013      Financial Services           152511.0
# 19     19  400011      Financial Services            22059.0
# 20     20  110070       Consumer Cyclical             9173.0
# 21     21  400030         Basic Materials            35869.0
# 22     22  400099      Consumer Defensive            21000.0
# 23     23  400051      Financial Services                NaN
# 24     24  400013      Financial Services            33582.0
# 25     25  560100              Technology           335186.0
# 26     26  700071      Consumer Defensive            23829.0
# 27     27  400051         Basic Materials            13483.0
# 28     28  400051      Financial Services            90000.0
# 29     29  400001             Industrials            49921.0
# 30     30  400018       Consumer Cyclical           260000.0
# 31     31  110070       Consumer Cyclical                NaN
# 32     32  122002      Consumer Defensive             7910.0
# 33     33  110003               Utilities                NaN
# 34     34  110070                  Energy                NaN
# 35     35  122001               Utilities                NaN
# 36     36  400021                  Energy           236334.0
# 37     37  400021      Financial Services           244250.0
# 38     38  400069      Financial Services            18401.0
# 39     39  700001         Basic Materials             6445.0
# 40     40  400063              Healthcare                NaN
# 41     41  400018       Consumer Cyclical            73608.0
# 42     42  400001         Basic Materials            65000.0
# 43     43  400001              Technology           606331.0
# 44     44  400001      Consumer Defensive             2932.0
# 45     45  411057              Technology           158035.0
# 46     46  560100       Consumer Cyclical             7263.0
# 47     47  400093         Basic Materials            21942.0
# 48     48  400051         Basic Materials            13054.0
# 49     49  560035              Technology           258574.0
#
#                                   longBusinessSummary       city  \
# 0   Adani Ports and Special Economic Zone Limited,...  Ahmedabad
# 1   Apollo Hospitals Enterprise Limited, together ...    Chennai
# 2   Asian Paints Limited, together with its subsid...     Mumbai
# 3   Axis Bank Limited provides various financial p...     Mumbai
# 4   Bajaj Auto Limited develops, manufactures, and...       Pune
# 5   Bajaj Finance Limited operates as a non-bankin...       Pune
# 6   Bajaj Finserv Ltd., through its subsidiaries, ...       Pune
# 7   Bharti Airtel Limited operates as a telecommun...  New Delhi
# 8   Bharat Petroleum Corporation Limited refines c...     Mumbai
# 9   Britannia Industries Limited manufactures and ...  Bengaluru
# 10  Cipla Limited, together with its subsidiaries,...     Mumbai
# 11  Coal India Limited, together with its subsidia...    Kolkata
# 12  Divi's Laboratories Limited manufactures and s...  Hyderabad
# 13  Dr. Reddy's Laboratories Limited, together wit...  Hyderabad
# 14  Eicher Motors Limited, an automobile company, ...   Gurugram
# 15  Grasim Industries Limited operates in fibre, y...     Mumbai
# 16  HCL Technologies Limited offers software devel...      Noida
# 17  Housing Development Finance Corporation Limite...     Mumbai
# 18  HDFC Bank Limited provides banking and financi...     Mumbai
# 19  HDFC Life Insurance Company Limited provides i...     Mumbai
# 20  Hero MotoCorp Limited manufactures and sells m...  New Delhi
# 21  Hindalco Industries Limited, together with its...     Mumbai
# 22  Hindustan Unilever Limited, a consumer goods c...     Mumbai
# 23  ICICI Bank Limited provides various banking pr...     Mumbai
# 24  IndusInd Bank Limited provides various banking...     Mumbai
# 25  Infosys Limited, together with its subsidiarie...  Bengaluru
# 26  ITC Limited engages in the fast-moving consume...    Kolkata
# 27  JSW Steel Limited engages in the manufacture a...     Mumbai
# 28  Kotak Mahindra Bank Limited, provides banking ...     Mumbai
# 29  Larsen & Toubro Limited engages in engineering...     Mumbai
# 30  Mahindra & Mahindra Limited provides mobility ...     Mumbai
# 31  Maruti Suzuki India Limited manufactures, purc...  New Delhi
# 32  Nestlé India Limited manufactures and sells fo...   Gurugram
# 33  NTPC Limited generates and sells bulk power to...  New Delhi
# 34  Oil and Natural Gas Corporation Limited explor...  New Delhi
# 35  Power Grid Corporation of India Limited, a cen...   Gurugram
# 36  Reliance Industries Limited engages in hydroca...     Mumbai
# 37  State Bank of India provides various banking p...     Mumbai
# 38  SBI Life Insurance Company Limited operates as...     Mumbai
# 39  Shree Cement Limited manufactures and sells ce...    Kolkata
# 40  Sun Pharmaceutical Industries Limited, a gener...     Mumbai
# 41  Tata Motors Limited designs, develops, manufac...     Mumbai
# 42  Tata Steel Limited manufactures and distribute...     Mumbai
# 43  Tata Consultancy Services Limited provides inf...     Mumbai
# 44  Tata Consumer Products Limited, together with ...     Mumbai
# 45  Tech Mahindra Limited provides information tec...       Pune
# 46  Titan Company Limited, together with its subsi...  Bengaluru
# 47  UltraTech Cement Limited, together with its su...     Mumbai
# 48  UPL Limited engages in the provision of sustai...     Mumbai
# 49  Wipro Limited operates as information technolo...  Bengaluru
#
#               phone country  \
# 0   91 79 2656 5555   India
# 1              None   India
# 2   91 22 6218 1000   India
# 3   91 22 2425 2525   India
# 4   91 20 2747 2851   India
# 5   91 20 7157 6403   India
# 6   91 20 7157 6064   India
# 7   91 11 4666 6100   India
# 8   91 22 2271 3000   India
# 9   91 80 3768 7100   India
# 10  91 22 2482 6000   India
# 11  91 33 2324 5555   India
# 12  91 40 6696 6300   India
# 13  91 40 4900 2900   India
# 14  91 12 4441 5600   India
# 15  91 22 6652 5000   India
# 16  91 11 2643 6336   India
# 17  91 22 6631 6000   India
# 18  91 22 6652 1000   India
# 19  91 22 6751 6666   India
# 20  91 11 4604 4220   India
# 21  91 22 6662 6666   India
# 22  91 22 5043 3000   India
# 23  91 22 2653 1414   India
# 24  91 22 2423 1999   India
# 25  91 80 2852 0261   India
# 26  91 33 2288 9371   India
# 27  91 22 4286 1000   India
# 28  91 22 6166 0001   India
# 29  91 22 6752 5656   India
# 30  91 22 2490 1441   India
# 31  91 11 4678 1000   India
# 32  91 12 4394 0000   India
# 33  91 11 2438 7333   India
# 34  91 11 2675 4073   India
# 35  91 12 4282 2000   India
# 36  91 22 3555 5000   India
# 37  91 22 2274 0841   India
# 38  91 22 6191 0000   India
# 39  91 33 2230 9601   India
# 40  91 22 4324 4324   India
# 41  91 22 6757 7200   India
# 42  91 22 6665 8282   India
# 43  91 22 6778 9595   India
# 44  91 22 6121 8400   India
# 45  91 20 4225 0000   India
# 46  91 80 6704 7000   India
# 47  91 22 6691 7800   India
# 48  91 22 7152 8000   India
# 49  91 80 2844 0011   India
#
#                                               website  maxAge  ...   dayHigh  \
# 0                          https://www.adaniports.com       1  ...    875.00
# 1                     https://www.apollohospitals.com       1  ...   4354.10
# 2                         https://www.asianpaints.com       1  ...   3500.00
# 3                            https://www.axisbank.com       1  ...    754.15
# 4                           https://www.bajajauto.com       1  ...   3594.95
# 5   https://www.bajajfinserv.in/corporate-bajaj-fi...       1  ...   7379.95
# 6   https://www.bajajfinserv.in/corporate-bajaj-fi...       1  ...   1715.75
# 7                               https://www.airtel.in       1  ...    765.00
# 8                      https://www.bharatpetroleum.in       1  ...    312.00
# 9                             https://britannia.co.in       1  ...   3889.80
# 10                              https://www.cipla.com       1  ...   1104.90
# 11                           https://www.coalindia.in       1  ...    219.70
# 12                          https://www.divislabs.com       1  ...   3712.00
# 13                           https://www.drreddys.com       1  ...   4200.00
# 14                       https://www.eichermotors.com       1  ...   3615.00
# 15                             https://www.grasim.com       1  ...   1696.95
# 16                            https://www.hcltech.com       1  ...    921.45
# 17                               https://www.hdfc.com       1  ...   2323.90
# 18                           https://www.hdfcbank.com       1  ...   1440.00
# 19                           https://www.hdfclife.com       1  ...    526.90
# 20                       https://www.heromotocorp.com       1  ...   2735.00
# 21                           https://www.hindalco.com       1  ...    379.95
# 22                              https://www.hul.co.in       1  ...   2713.75
# 23                          https://www.icicibank.com       1  ...    874.85
# 24                           https://www.indusind.com       1  ...   1178.00
# 25                            https://www.infosys.com       1  ...   1406.50
# 26                          https://www.itcportal.com       1  ...    339.55
# 27                                 https://www.jsw.in       1  ...    650.95
# 28                              https://www.kotak.com       1  ...   1834.85
# 29                       https://www.larsentoubro.com       1  ...   1864.00
# 30                           https://www.mahindra.com       1  ...   1252.90
# 31                       https://www.marutisuzuki.com       1  ...   8908.95
# 32                              https://www.nestle.in       1  ...  18795.00
# 33                             https://www.ntpc.co.in       1  ...    161.65
# 34                          https://www.ongcindia.com       1  ...    127.90
# 35                           https://www.powergrid.in       1  ...    207.90
# 36                                https://www.ril.com       1  ...   2426.00
# 37                              https://www.sbi.co.in       1  ...    550.90
# 38                          https://www.sbilife.co.in       1  ...   1270.65
# 39                        https://www.shreecement.com       1  ...  21483.70
# 40                          https://www.sunpharma.com       1  ...    909.85
# 41                         https://www.tatamotors.com       1  ...    404.00
# 42                          https://www.tatasteel.com       1  ...    101.35
# 43                                https://www.tcs.com       1  ...   3025.00
# 44                       https://www.tataconsumer.com       1  ...    801.40
# 45                       https://www.techmahindra.com       1  ...   1045.00
# 46                        https://www.titancompany.in       1  ...   2679.55
# 47                    https://www.ultratechcement.com       1  ...   6273.95
# 48                            https://www.upl-ltd.com       1  ...    687.85
# 49                              https://www.wipro.com       1  ...    401.40
#
#    coinMarketCapLink regularMarketPrice preMarketPrice  \
# 0               None             844.20           None
# 1               None            4242.95           None
# 2               None            3470.65           None
# 3               None             737.50           None
# 4               None            3541.90           None
# 5               None            7242.85           None
# 6               None            1679.55           None
# 7               None             760.60           None
# 8               None             310.65           None
# 9               None            3824.15           None
# 10              None            1098.70           None
# 11              None             213.90           None
# 12              None            3680.20           None
# 13              None            4181.60           None
# 14              None            3570.55           None
# 15              None            1682.50           None
# 16              None             918.75           None
# 17              None            2289.15           None
# 18              None            1413.85           None
# 19              None             520.85           None
# 20              None            2638.25           None
# 21              None             373.60           None
# 22              None            2679.25           None
# 23              None             852.55           None
# 24              None            1165.10           None
# 25              None            1393.55           None
# 26              None             334.85           None
# 27              None             637.00           None
# 28              None            1799.30           None
# 29              None            1841.20           None
# 30              None            1235.75           None
# 31              None            8774.05           None
# 32              None           18672.65           None
# 33              None             159.00           None
# 34              None             124.45           None
# 35              None             204.85           None
# 36              None            2396.25           None
# 37              None             536.50           None
# 38              None            1242.30           None
# 39              None           21163.25           None
# 40              None             897.15           None
# 41              None             398.80           None
# 42              None              97.65           None
# 43              None            3017.45           None
# 44              None             797.85           None
# 45              None            1022.50           None
# 46              None            2600.35           None
# 47              None            6192.85           None
# 48              None             677.70           None
# 49              None             398.40           None
#
#                                          logo_url  trailingPegRatio  \
# 0        https://logo.clearbit.com/adaniports.com               NaN
# 1   https://logo.clearbit.com/apollohospitals.com               NaN
# 2       https://logo.clearbit.com/asianpaints.com               NaN
# 3          https://logo.clearbit.com/axisbank.com               NaN
# 4         https://logo.clearbit.com/bajajauto.com               NaN
# 5       https://logo.clearbit.com/bajajfinserv.in               NaN
# 6       https://logo.clearbit.com/bajajfinserv.in               NaN
# 7             https://logo.clearbit.com/airtel.in               NaN
# 8    https://logo.clearbit.com/bharatpetroleum.in               NaN
# 9       https://logo.clearbit.com/britannia.co.in               NaN
# 10            https://logo.clearbit.com/cipla.com               NaN
# 11         https://logo.clearbit.com/coalindia.in               NaN
# 12        https://logo.clearbit.com/divislabs.com               NaN
# 13         https://logo.clearbit.com/drreddys.com            1.1776
# 14     https://logo.clearbit.com/eichermotors.com               NaN
# 15           https://logo.clearbit.com/grasim.com               NaN
# 16          https://logo.clearbit.com/hcltech.com               NaN
# 17             https://logo.clearbit.com/hdfc.com               NaN
# 18         https://logo.clearbit.com/hdfcbank.com               NaN
# 19         https://logo.clearbit.com/hdfclife.com               NaN
# 20     https://logo.clearbit.com/heromotocorp.com               NaN
# 21         https://logo.clearbit.com/hindalco.com               NaN
# 22            https://logo.clearbit.com/hul.co.in               NaN
# 23        https://logo.clearbit.com/icicibank.com               NaN
# 24         https://logo.clearbit.com/indusind.com               NaN
# 25          https://logo.clearbit.com/infosys.com               NaN
# 26        https://logo.clearbit.com/itcportal.com               NaN
# 27               https://logo.clearbit.com/jsw.in               NaN
# 28            https://logo.clearbit.com/kotak.com               NaN
# 29     https://logo.clearbit.com/larsentoubro.com               NaN
# 30         https://logo.clearbit.com/mahindra.com               NaN
# 31     https://logo.clearbit.com/marutisuzuki.com               NaN
# 32            https://logo.clearbit.com/nestle.in               NaN
# 33           https://logo.clearbit.com/ntpc.co.in               NaN
# 34        https://logo.clearbit.com/ongcindia.com               NaN
# 35         https://logo.clearbit.com/powergrid.in               NaN
# 36              https://logo.clearbit.com/ril.com               NaN
# 37            https://logo.clearbit.com/sbi.co.in               NaN
# 38        https://logo.clearbit.com/sbilife.co.in               NaN
# 39      https://logo.clearbit.com/shreecement.com               NaN
# 40        https://logo.clearbit.com/sunpharma.com               NaN
# 41       https://logo.clearbit.com/tatamotors.com               NaN
# 42        https://logo.clearbit.com/tatasteel.com               NaN
# 43              https://logo.clearbit.com/tcs.com               NaN
# 44     https://logo.clearbit.com/tataconsumer.com               NaN
# 45     https://logo.clearbit.com/techmahindra.com               NaN
# 46      https://logo.clearbit.com/titancompany.in               NaN
# 47  https://logo.clearbit.com/ultratechcement.com               NaN
# 48          https://logo.clearbit.com/upl-ltd.com               NaN
# 49            https://logo.clearbit.com/wipro.com               NaN
#
#     underlyingSymbol  underlyingExchangeSymbol  headSymbol  \
# 0               None                      None        None
# 1               None                      None        None
# 2               None                      None        None
# 3               None                      None        None
# 4               None                      None        None
# 5               None                      None        None
# 6               None                      None        None
# 7               None                      None        None
# 8               None                      None        None
# 9               None                      None        None
# 10              None                      None        None
# 11              None                      None        None
# 12              None                      None        None
# 13              None                      None        None
# 14              None                      None        None
# 15              None                      None        None
# 16              None                      None        None
# 17              None                      None        None
# 18              None                      None        None
# 19              None                      None        None
# 20              None                      None        None
# 21              None                      None        None
# 22              None                      None        None
# 23              None                      None        None
# 24              None                      None        None
# 25              None                      None        None
# 26              None                      None        None
# 27              None                      None        None
# 28              None                      None        None
# 29              None                      None        None
# 30              None                      None        None
# 31              None                      None        None
# 32              None                      None        None
# 33              None                      None        None
# 34              None                      None        None
# 35              None                      None        None
# 36              None                      None        None
# 37              None                      None        None
# 38              None                      None        None
# 39              None                      None        None
# 40              None                      None        None
# 41              None                      None        None
# 42              None                      None        None
# 43              None                      None        None
# 44              None                      None        None
# 45              None                      None        None
# 46              None                      None        None
# 47              None                      None        None
# 48              None                      None        None
# 49              None                      None        None
#
#                                     uuid
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# 5                                   None
# 6                                   None
# 7                                   None
# 8                                   None
# 9                                   None
# 10                                  None
# 11                                  None
# 12                                  None
# 13                                  None
# 14                                  None
# 15                                  None
# 16                                  None
# 17                                  None
# 18                                  None
# 19                                  None
# 20                                  None
# 21                                  None
# 22  b9a3be7e-e399-3e49-b6b7-ed2d603368eb
# 23  d21a6484-0aac-330e-a9d9-9718a5f952f0
# 24  9781daee-0bea-3be5-a327-74d3f4bfb8e7
# 25  6e0e3969-0bf9-3676-8a5c-d91501277ca6
# 26  2d1c10cc-4829-3114-aea5-57a0600cb464
# 27  266ea77e-9e0c-34f3-97a6-fc70e087818c
# 28  e9b8d17b-5451-3759-a200-d6130e6b96d7
# 29  51a5c7d9-eafd-371d-afd4-cad7e0dbbd48
# 30  08f0f1eb-593a-354a-a5bd-38231342ca8a
# 31  2b186ade-01ba-3c85-b686-b892dbd32072
# 32  12d28da0-1b60-3bd0-9b1f-2bb8edb342e9
# 33  8ba23af1-4242-3e1c-8797-3049e46b897c
# 34  4bbe7a6f-a7cd-39fe-bc9a-e211fb881c45
# 35  304a81d9-2610-307c-99cf-d548f87634cb
# 36  6fb3aba7-25b9-3826-85a7-5fb8a94f4e84
# 37  f8326bb6-61ba-333c-a8c6-52d3a1bf3c06
# 38  9623c870-f343-3ce2-8f67-2ee8d552ff38
# 39  7fa9f112-2d77-37a2-b40d-8924292b4775
# 40  aaf5d89c-04c2-30f3-b8ab-32d98e120d78
# 41  ddba5579-685b-35a6-8ca9-fdc0ae8f12f6
# 42  fadf0ed1-ada5-3bab-993c-4f6b06474dd3
# 43  cc4c841e-ad42-3fdb-8d9f-b26fa8acd1cf
# 44  95870c70-07ec-33af-a4e3-6c8e057f1afd
# 45  99084168-d40f-3aaa-a5c8-3d92f955df00
# 46  e0b199f6-7ef1-3919-a462-9165d47a615e
# 47  ac3a92dd-3060-34f8-99b5-d2813b6f3672
# 48  e2080cbb-d21c-3bb2-9b38-6fec3b132fef
# 49  9b2184f0-c004-3a57-8738-9263da046c6c
#
# [50 rows x 159 columns]

# %%
pd.read_sql("select * from stockprice_table", mysql_engine)
# Out:
#     index ('Date', '')  ('NESTLEIND.NS', 'Open')  ('NESTLEIND.NS', 'High')  \
# 0    None   2021-09-28              19690.000000              19718.650391
# 1    None   2021-09-29              19544.750000              19700.000000
# 2    None   2021-09-30              19478.300781              19589.949219
# 3    None   2021-10-01              19445.000000              19644.949219
# 4    None   2021-10-04              19549.949219              19650.000000
# ..    ...          ...                       ...                       ...
# 243  None   2022-09-20              18810.000000              18920.000000
# 244  None   2022-09-21              18616.000000              18889.400391
# 245  None   2022-09-22              18649.900391              18835.000000
# 246  None   2022-09-23              18591.000000              18656.199219
# 247  None   2022-09-26              18495.800781              18889.900391
#
#      ('NESTLEIND.NS', 'Low')  ('NESTLEIND.NS', 'Close')  \
# 0               19459.050781               19544.750000
# 1               19421.650391               19506.750000
# 2               19316.150391               19445.550781
# 3               19252.050781               19549.949219
# 4               19362.050781               19492.949219
# ..                       ...                        ...
# 243             18575.099609               18616.650391
# 244             18591.050781               18649.900391
# 245             18580.550781               18638.300781
# 246             18450.050781               18495.900391
# 247             18397.550781               18453.300781
#
#      ('NESTLEIND.NS', 'Adj Close')  ('NESTLEIND.NS', 'Volume')  \
# 0                     19429.757812                       57686
# 1                     19391.982422                       46295
# 2                     19331.142578                       44373
# 3                     19434.927734                       39869
# 4                     19378.261719                       32796
# ..                             ...                         ...
# 243                   18616.650391                       83800
# 244                   18649.900391                       46299
# 245                   18638.300781                       77931
# 246                   18495.900391                       35842
# 247                   18453.300781                      113085
#
#      ('UPL.NS', 'Open')  ('UPL.NS', 'High')  ...  ('HINDALCO.NS', 'Low')  \
# 0            728.000000          732.900024  ...              475.049988
# 1            711.900024          722.900024  ...              473.399994
# 2            717.150024          719.900024  ...              485.600006
# 3            707.000000          714.049988  ...              473.450012
# 4            713.099976          719.900024  ...              481.000000
# ..                  ...                 ...  ...                     ...
# 243          715.849976          723.599976  ...              415.799988
# 244          717.000000          724.450012  ...              410.799988
# 245          709.099976          726.599976  ...              403.500000
# 246          724.000000          727.299988  ...              394.450012
# 247          698.000000          701.950012  ...              369.600006
#
#      ('HINDALCO.NS', 'Close')  ('HINDALCO.NS', 'Adj Close')  \
# 0                  478.149994                    478.149994
# 1                  494.149994                    494.149994
# 2                  487.950012                    487.950012
# 3                  484.350006                    484.350006
# 4                  505.700012                    505.700012
# ..                        ...                           ...
# 243                421.450012                    421.450012
# 244                411.350006                    411.350006
# 245                412.100006                    412.100006
# 246                396.350006                    396.350006
# 247                373.399994                    373.399994
#
#      ('HINDALCO.NS', 'Volume')  ('ITC.NS', 'Open')  ('ITC.NS', 'High')  \
# 0                      6148679          239.850006          241.600006
# 1                      9508220          236.000000          241.399994
# 2                     14333358          239.899994          240.399994
# 3                      8072310          235.199997          237.000000
# 4                     10303925          236.000000          238.350006
# ..                         ...                 ...                 ...
# 243                    8758050          338.750000          339.600006
# 244                    6859320          336.000000          345.200012
# 245                    8704463          341.000000          348.750000
# 246                    9228856          347.500000          349.549988
# 247                   13092570          344.850006          345.950012
#
#      ('ITC.NS', 'Low')  ('ITC.NS', 'Close')  ('ITC.NS', 'Adj Close')  \
# 0           236.300003           237.750000               232.380295
# 1           235.699997           238.100006               232.722397
# 2           235.250000           236.149994               230.816422
# 3           232.899994           235.350006               230.034500
# 4           235.399994           236.600006               231.256271
# ..                 ...                  ...                      ...
# 243         335.000000           336.000000               336.000000
# 244         335.500000           340.950012               340.950012
# 245         340.899994           345.049988               345.049988
# 246         343.299988           346.399994               346.399994
# 247         331.750000           332.600006               332.600006
#
#      ('ITC.NS', 'Volume')
# 0                15713947
# 1                15450046
# 2                16357902
# 3                15956143
# 4                10686552
# ..                    ...
# 243               9526068
# 244              20992080
# 245              24179987
# 246              22838807
# 247              16205789
#
# [248 rows x 302 columns]
